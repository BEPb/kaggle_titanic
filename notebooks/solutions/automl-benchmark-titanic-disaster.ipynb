# %% [markdown]
# # AutoML Benchmark - Titanic Disaster
#
# This notebook presents a lot of Auto ML (Machine Learning) packages for classification task. We are going to perform an AutoML benchmark in [Titanic - Machine Learning from Disaster](https://www.kaggle.com/competitions/titanic). In the end, I hope you are going to be able to apply these solutions in our projects.
#
# > **Summary** - AutoML Classification in real Data.
# > Content for intermediate level in Machine Learning and Data Science!
#
# <a id="ToC"></a>
# ## Table of Contents
# - [Data Exploration](#data)
#     - Label Encoder
#     - Data Imputer
# - [AutoML](#automl)
#     - [Lazy Predict](#automl-lazypredict)
#     - [hyperopt-sklearn](#automl-hyperopt)
#     - [auto-sklearn](#automl-sklearn)
#     - [TPOT](#automl-tpot)
#     - [MLJAR](#automl-mljar)
#     - [FLAML](#automl-flaml)
#     - [AutoGluon](#automl-autogluon)
#     - [H2O](#automl-h2o)
#     - [AutoKeras](#automl-autokeras)
#     - [MLBox](#automl-mlbox)
#     - [PyCaret](#automl-pycaret)

# %%
# %%capture
# Install main packages
# !pip install numpy==1.11.0 scikit-learn==1.0.2
# !pip install matplotlib==3.5.3 seaborn==0.11.2

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Restart kernel, for new downloaded packages
# -- it didn't work in Kaggle
# https://stackoverflow.com/questions/37751120/restart-ipython-kernel-with-a-command-from-a-cell

# %% [markdown]
# <a id="data"></a>
#
# ---
# # Data Exploration
#
# We are going to normalize the data (using an `Enconder`) and input missing data (using an `Imputer`).
#
# [> Back to Table of Contents](#ToC)

# %%
# Main imports
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# List the files
import os

for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
# Train set
train = pd.read_csv("/kaggle/input/titanic/train.csv")
train.sort_values("PassengerId", inplace=True)
print("train", train.shape)
display(train.head(3))

# Test set
test = pd.read_csv("/kaggle/input/titanic/test.csv")
test.sort_values("PassengerId", inplace=True)
print("test", test.shape)
display(test.head(3))

# Submission
submission = pd.read_csv("/kaggle/input/titanic/gender_submission.csv")
submission.sort_values("PassengerId", inplace=True)
print("submission", submission.shape)
display(submission.head(3))
# Out:
# train (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# test (418, 11)
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S
# 2      0  240276  9.6875   NaN        Q
# submission (418, 2)
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0

# %% [markdown]
# ## Label Enconder
#
# Many algorithms cannot handle with `str` features. Thus we are going to encoder them into `int`/`float` features.

# %%
# Check train set
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
# Label encoder
from sklearn.preprocessing import LabelEncoder

# Encoding
pre_columns = ["Sex", "Embarked"]
encoders = {}
for c in pre_columns:
    encoder = LabelEncoder()
    train[c] = encoder.fit_transform(train[c].astype("str"))
    encoders[c] = encoder

# %% [markdown]
# ## Input Missing Values
#
# We have few columns with missing data, such as **Age** and **Cabin**. We are going to use an `Imputer` to fill in these empty fields.

# %%
# Check train set
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 90.5+ KB

# %%
# Data imputer
from sklearn.impute import KNNImputer

# Reference columns
x_columns = ["Pclass", "Sex", "SibSp", "Parch", "Fare", "Age", "Embarked"]
imputer = KNNImputer(n_neighbors=3, weights="uniform")
train[x_columns] = imputer.fit_transform(train[x_columns])

# %%
display(train[x_columns].info())
display(train[x_columns].sample(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    float64
#  1   Sex       891 non-null    float64
#  2   SibSp     891 non-null    float64
#  3   Parch     891 non-null    float64
#  4   Fare      891 non-null    float64
#  5   Age       891 non-null    float64
#  6   Embarked  891 non-null    float64
# dtypes: float64(7)
# memory usage: 55.7 KB
# None
#      Pclass  Sex  SibSp  Parch     Fare        Age  Embarked
# 432     2.0  0.0    1.0    0.0  26.0000  42.000000       2.0
# 686     3.0  1.0    4.0    1.0  39.6875  14.000000       2.0
# 136     1.0  0.0    0.0    2.0  26.2833  19.000000       2.0
# 834     3.0  1.0    0.0    0.0   8.3000  18.000000       2.0
# 552     3.0  1.0    0.0    0.0   7.8292  33.833333       1.0

# %%
def preprocessing(X:pd.DataFrame):
    """Preprocessing: label encoder and imputer"""
    global pre_columns, encoders
    global x_columns, imputer

    # label encoder, imputer
    for c in pre_columns: X[c] = encoders[c].transform(X[c].astype("str"))
    X[x_columns] = imputer.fit_transform(X[x_columns])
    return X

# %%
# Process test set, using the trained parameters
test = preprocessing(test)
test[x_columns]
# Out:
#      Pclass  Sex  SibSp  Parch      Fare        Age  Embarked
# 0       3.0  1.0    0.0    0.0    7.8292  34.500000       1.0
# 1       3.0  0.0    1.0    0.0    7.0000  47.000000       2.0
# 2       2.0  1.0    0.0    0.0    9.6875  62.000000       1.0
# 3       3.0  1.0    0.0    0.0    8.6625  27.000000       2.0
# 4       3.0  0.0    1.0    1.0   12.2875  22.000000       2.0
# ..      ...  ...    ...    ...       ...        ...       ...
# 413     3.0  1.0    0.0    0.0    8.0500  29.666667       2.0
# 414     1.0  0.0    0.0    0.0  108.9000  39.000000       0.0
# 415     3.0  1.0    0.0    0.0    7.2500  38.500000       2.0
# 416     3.0  1.0    0.0    0.0    8.0500  29.666667       2.0
# 417     3.0  1.0    1.0    1.0   22.3583  18.666667       0.0
#
# [418 rows x 7 columns]

# %% [markdown]
# <a href="#ToC"><span class="label label-info" style="font-size: 125%">> Back to Table of Contents</span></a>

# %% [markdown]
# <a id="automl"></a>
#
# ---
# # AutoML
#
# Automated machine learning (AutoML) is the process of automating the tasks of applying machine learning to real-world problems. AutoML potentially includes every stage from beginning with a raw dataset to building a machine learning model ready for deployment. [Wikipedia](https://en.wikipedia.org/wiki/Automated_machine_learning)
#
# [> Back to Table of Contents](#ToC)

# %%
# Store experiments results
experiment = {}
best_model_name = None

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(model_name, y_test, y_pred, focus_metric="F1"):
    '''Evaluate a model'''
    global experiment, best_model, best_model_name

    acc = accuracy_score(y_test, y_pred)
    pre = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred)    
    experiment[model_name] = {"Acc":acc, "Pre":pre, "Rec":rec, "F1":f1}

    print(f"Accuracy : {acc:.4f}")
    print(f"Precision: {pre:.4f}")
    print(f"Recall   : {rec:.4f}")
    print(f"F1-score : {f1:.4f}")

    if not isinstance(best_model_name, tuple) or best_model_name[1] < experiment[model_name][focus_metric]:
        best_model_name = (model_name, experiment[model_name][focus_metric])

# %%
def create_submission(predict, X_test, submission, filename, pred_column="Survived"):
    '''Generate a submission file'''
    preds = predict(X_test)
    submission[pred_column] = preds
    submission[pred_column] = submission[pred_column].astype('int32')
    submission.to_csv(filename, index=False)

# %% [markdown]
# ## Dataset

# %%
# Create X_train, y_train, and X_test
seed_number = 28
label_column = "Survived"
X_train, y_train = train[x_columns], train[label_column]
X_test = test[x_columns]

# %%
# Save for fast recovery (when restart the notebook)
np.savetxt('X_train.np', X_train, delimiter=';')
np.savetxt('y_train.np', y_train, delimiter=';')
np.savetxt('X_test.np', X_test, delimiter=';')

# %% [markdown]
# <a href="#ToC"><span class="label label-info" style="font-size: 125%">Back to Table of Contents</span></a>

# %% [markdown]
# <a id="automl-lazypredict"></a>
#
# ---
# # Lazy Predict
#
# - [GitHub](https://github.com/shankarpandala/lazypredict)
# - [Documentation](https://lazypredict.readthedocs.io/)
#
# **Lazy Predict** helps build a lot of basic models (from scikit-learn) without much code and helps understand which models works better without any parameter tuning.
# In another words, Lazy Predict is a good library to test multiple solutions at once quickly. It only includes preprocessing and model training, thus we cannot perform any finetunning.
#
# [> Back to Table of Contents](#ToC)

# %%
# %%capture
# install Lazy Predict
# !pip install lazypredict==0.2.12

# %%
# %%time
from lazypredict.Supervised import LazyClassifier

automl = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
results, _ = automl.fit(X_train, X_train, y_train, y_train)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# 100%|██████████| 29/29 [00:02<00:00, 10.70it/s]
# CPU times: user 6.25 s, sys: 921 ms, total: 7.17 s
# Wall time: 4.91 s

# %%
# Experiments
display(results)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.98               0.98     0.98      0.98
# DecisionTreeClassifier             0.98               0.98     0.98      0.98
# ExtraTreeClassifier                0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# BaggingClassifier                  0.97               0.96     0.96      0.97
# XGBClassifier                      0.97               0.96     0.96      0.97
# LGBMClassifier                     0.95               0.94     0.94      0.95
# LabelPropagation                   0.92               0.90     0.90      0.92
# LabelSpreading                     0.91               0.90     0.90      0.91
# KNeighborsClassifier               0.87               0.86     0.86      0.87
# AdaBoostClassifier                 0.83               0.82     0.82      0.83
# SVC                                0.84               0.82     0.82      0.84
# NuSVC                              0.82               0.80     0.80      0.82
# QuadraticDiscriminantAnalysis      0.81               0.80     0.80      0.81
# LinearSVC                          0.81               0.79     0.79      0.81
# CalibratedClassifierCV             0.81               0.79     0.79      0.80
# LinearDiscriminantAnalysis         0.80               0.79     0.79      0.80
# RidgeClassifier                    0.80               0.79     0.79      0.80
# RidgeClassifierCV                  0.80               0.79     0.79      0.80
# LogisticRegression                 0.80               0.78     0.78      0.80
# GaussianNB                         0.79               0.78     0.78      0.79
# NearestCentroid                    0.77               0.77     0.77      0.78
# PassiveAggressiveClassifier        0.77               0.76     0.76      0.77
# BernoulliNB                        0.78               0.76     0.76      0.78
# SGDClassifier                      0.76               0.75     0.75      0.76
# Perceptron                         0.73               0.72     0.72      0.73
# DummyClassifier                    0.62               0.50     0.50      0.47
#
#                                Time Taken
# Model
# RandomForestClassifier               0.26
# DecisionTreeClassifier               0.02
# ExtraTreeClassifier                  0.02
# ExtraTreesClassifier                 0.26
# BaggingClassifier                    0.06
# XGBClassifier                        0.57
# LGBMClassifier                       0.27
# LabelPropagation                     0.11
# LabelSpreading                       0.14
# KNeighborsClassifier                 0.05
# AdaBoostClassifier                   0.15
# SVC                                  0.06
# NuSVC                                0.08
# QuadraticDiscriminantAnalysis        0.03
# LinearSVC                            0.09
# CalibratedClassifierCV               0.25
# LinearDiscriminantAnalysis           0.05
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.02
# LogisticRegression                   0.03
# GaussianNB                           0.02
# NearestCentroid                      0.02
# PassiveAggressiveClassifier          0.02
# BernoulliNB                          0.02
# SGDClassifier                        0.02
# Perceptron                           0.02
# DummyClassifier                      0.02

# %%
# Get best mode
cls_name = results.iloc[0].name
model = automl.models[cls_name]
# display(model)

# %%
# Evaluation
y_pred = model.predict(X_train)
evaluate_model("lazypredict", y_train, y_pred)
# Out:
# Accuracy : 0.9820
# Precision: 0.9880
# Recall   : 0.9649
# F1-score : 0.9763

# %%
# Submission
create_submission(model.predict, X_test, submission, "submission-lazypredict.csv")

# %%
# Results
pd.DataFrame(experiment).T.style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_16fdc_row0_col0, #T_16fdc_row0_col1, #T_16fdc_row0_col2, #T_16fdc_row0_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_16fdc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Acc</th>
#       <th class="col_heading level0 col1" >F1</th>
#       <th class="col_heading level0 col2" >Pre</th>
#       <th class="col_heading level0 col3" >Rec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16fdc_level0_row0" class="row_heading level0 row0" >lazypredict</th>
#       <td id="T_16fdc_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_16fdc_row0_col1" class="data row0 col1" >0.98</td>
#       <td id="T_16fdc_row0_col2" class="data row0 col2" >0.99</td>
#       <td id="T_16fdc_row0_col3" class="data row0 col3" >0.96</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to install and use
# * **Good** - It presents nice results
# * **Simple** - It runs the scikit-learn models
#
# Features
# * **Good** - It includes preprocessing and model trainning - only
# * **Bad** - It does not include finetunning
#
# Public Score - 0.75598

# %% [markdown]
# <a id="automl-hyperopt"></a>
#
# ---
# # hyperopt-sklearn
#
# - [GitHub](https://github.com/hyperopt/hyperopt-sklearn)
# - [Documentation](http://hyperopt.github.io/hyperopt-sklearn/)
#
# **hyperopt-sklearn** (hyperparameter optimization for sklearn) is [hyperopt](https://github.com/hyperopt/hyperopt)-based model selection among machine learning algorithms in scikit-learn.
# In contrast with **Lazy Predict**, hyperopt-sklearn can perform hyperparameter tunning in the models.
#
# [> Back to Table of Contents](#ToC)

# %% [markdown]
# _This code is written in markdown, because it uses incompatible packages for this Jupyter Notebook_
#
# **Installation**
#
# ```python
# %%capture
# # install hyperopt-sklearn
# !pip install git+https://github.com/hyperopt/hyperopt-sklearn
# ```
#
# **Read data**
#
# ```python
# # Read data
# import numpy as np
# import pandas as pd
#
# X_train = np.loadtxt('X_train.np', delimiter=';')
# y_train = np.loadtxt('y_train.np', delimiter=';')
# X_test = np.loadtxt('X_test.np', delimiter=';')
# ```
#
# **AutoML**
#
# ```python
# %%time
# from hpsklearn import HyperoptEstimator
#
# automl = HyperoptEstimator(max_evals = 30, verbose=False)
# automl.fit(X_train, y_train)
# ```
#
# **Evaluation**
#
# ```python
# # Evaluation
# y_pred = automl.predict(X_train)
# evaluate_model("hyperopt-sklearn", y_train, y_pred)
# ```
#
# ```sh
# Accuracy : 0.8631
# Precision: 0.8216
# Recall   : 0.8216
# F1-score : 0.8216
# ```
#
# **Submission**
#
# ```python
# # Submission
# create_submission(automl.predict, X_test, submission, "submission-hyperopt-sklearn.csv")
# ```
#
# ```python
# # Results
# pd.DataFrame(experiment).T.style.highlight_max(axis=0)
# ```

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to use
# * **Good** - It presents nice results
# * **Simple** - It runs the scikit-learn models
# * **Bad** - It is complicate to install, contains few incompatible packages
#
# Features
# * **Good** - It includes model trainning and finetunning
# * **Bad** - It does not include preprocessing
#
# Public Score - 0.78229

# %% [markdown]
# <a id="automl-sklearn"></a>
#
# ---
# # auto-sklearn
#
# - [GitHub](https://github.com/automl/auto-sklearn)
# - [Documentation](https://automl.github.io/auto-sklearn/master/)
#
# **auto-sklearn** is an automated machine learning toolkit and a drop-in replacement for a scikit-learn estimator. In summary, it combines data preprocessing, feature preprocessing and classifier evaluation. Note, it not train simple models, auto-sklearn enseble models to get better performance. _Note, it uses the previous version of scikit-learn_.
#
# [> Back to Table of Contents](#ToC)

# %% [markdown]
# _This code is written in markdown, because it uses incompatible packages for this Jupyter Notebook_
#
# **Installation**
#
# ```python
# # %%capture
# # install dependencies
# !apt-get -y remove swig
# !apt-get -y install swig3.0 build-essential -y
# !ln -s /usr/bin/swig3.0 /usr/bin/swig
# !apt-get -y install build-essential
# # install auto-sklearn
# !pip install scikit-learn==0.24.2
# !pip install git+https://github.com/automl/auto-sklearn
# ```
#
# **Read data**
#
# ```python
# # Read data
# import numpy as np
# import pandas as pd
#
# X_train = np.loadtxt('X_train.np', delimiter=';')
# y_train = np.loadtxt('y_train.np', delimiter=';')
# X_test = np.loadtxt('X_test.np', delimiter=';')
# ```
#
# **AutoML**
#
# ```python
# %%time
# from autosklearn.classification import AutoSklearnClassifier
#
# automl = AutoSklearnClassifier(time_left_for_this_task=150, ensemble_kwargs = {'ensemble_size': 5}, seed=28)
# automl.fit(X_train, y_train)
# ```
#
# **Evaluation**
#
# ```python
# # Evaluation
# y_pred = automl.predict(X_train)
# evaluate_model("auto-sklearn", y_train, y_pred)
# ```
#
# ```sh
# Accuracy : 0.8698
# Precision: 0.8576
# Recall   : 0.7924
# F1-score : 0.8237
# ```
#
# **Submission**
#
# ```python
# create_submission(automl.predict, X_test, submission, "submission-auto-sklearn.csv")
# ```

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to use
# * **Good** - It presents nice results
# * **Simple** - It runs the scikit-learn models
# * **Bad** - It uses the outdated version of scikit-learn
#
# Features
# * **Good** - It includes preprocessing, model trainning and emsemble
# * **Bad** - It generates complicated emsemble models (combining over 10 models into a meta-model)
#
# Public Score - 0.74401

# %% [markdown]
# <a id="automl-tpot"></a>
#
# ---
# # TPOT
#
# - [GitHub](https://github.com/EpistasisLab/tpot)
# - [Documentation](http://epistasislab.github.io/tpot/)
#
# **TPOT** stands for Tree-based Pipeline Optimization Tool. It is a AutoML tool that optimizes machine learning pipelines using genetic programming.
# It looks a combination of **hyperopt-sklearn** finetunning and **auto-sklearn** data preprocessing, however, it does not emsemble the models - it keeps models simple and interpretable.
#
# [> Back to Table of Contents](#ToC)

# %%
# %%capture
# install TPOT
# !pip install deap update_checker tqdm stopit xgboost
# !pip install scikit-mdr skrebate
# !pip install tpot==0.11.7

# %%
# %%time
from tpot import TPOTClassifier

automl = TPOTClassifier(generations=5, population_size=20, verbosity=0, random_state=28)
automl.fit(X_train, y_train)
# Out:
# CPU times: user 3min 36s, sys: 44.9 s, total: 4min 21s
# Wall time: 3min
# TPOTClassifier(generations=5, population_size=20, random_state=28)

# %%
# Evaluation
y_pred = automl.predict(X_train)
evaluate_model("tpot", y_train, y_pred)
# Out:
# Accuracy : 0.8833
# Precision: 0.8864
# Recall   : 0.7982
# F1-score : 0.8400

# %%
# Submission
create_submission(automl.predict, X_test, submission, "submission-tpot.csv")

# %%
# Results
pd.DataFrame(experiment).T.style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_9d3fb_row0_col0, #T_9d3fb_row0_col1, #T_9d3fb_row0_col2, #T_9d3fb_row0_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_9d3fb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Acc</th>
#       <th class="col_heading level0 col1" >Pre</th>
#       <th class="col_heading level0 col2" >Rec</th>
#       <th class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d3fb_level0_row0" class="row_heading level0 row0" >lazypredict</th>
#       <td id="T_9d3fb_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_9d3fb_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_9d3fb_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_9d3fb_row0_col3" class="data row0 col3" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_9d3fb_level0_row1" class="row_heading level0 row1" >tpot</th>
#       <td id="T_9d3fb_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_9d3fb_row1_col1" class="data row1 col1" >0.89</td>
#       <td id="T_9d3fb_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_9d3fb_row1_col3" class="data row1 col3" >0.84</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to install and use
# * **Good** - It presents nice results
# * **Simple** - It runs the scikit-learn models
#
# Features
# * **Good** - It includes preprocessing, model trainning and finetunning
#
# Public Score - 0.76555 (good)

# %% [markdown]
# <a id="automl-mljar"></a>
#
# ---
# # MLJAR
#
# - [GitHub](https://github.com/mljar/mljar-supervised)
# - [Documentation](https://supervised.mljar.com/)
#
# The **mljar-supervised** is an AutoML package that works with tabular data. It abstracts the common way to preprocess the data, construct the machine learning models, and perform hyper-parameters tuning to find the best model. Also, it supports explainability and automatic exploratory data analysis. It contains more features than **TPOT**, but it is more complex too.
#
# [> Back to Table of Contents](#ToC)

# %%
# %%capture
# install MLJar
# !pip install mljar-supervised==0.11.3

# %%
# %%time
from supervised.automl import AutoML

automl = AutoML(mode="Compete", total_time_limit=1*60)
automl.fit(X_train, y_train)
# Out:
# AutoML directory: AutoML_1
# The task is binary_classification with evaluation metric logloss
# AutoML will use algorithms: ['Decision Tree', 'Linear', 'Random Forest', 'Extra Trees', 'LightGBM', 'Xgboost', 'CatBoost', 'Neural Network', 'Nearest Neighbors']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree logloss 0.397652 trained in 0.81 seconds
# Disable stacking for split validation
# * Step simple_algorithms will try to check up to 3 models
# 2_DecisionTree logloss 0.625735 trained in 1.06 seconds
# 3_DecisionTree logloss 0.625735 trained in 1.07 seconds
# 4_Linear logloss 0.403434 trained in 2.33 seconds
# * Step default_algorithms will try to check up to 7 models
# 5_Default_LightGBM logloss 0.460557 trained in 1.51 seconds
# 6_Default_Xgboost logloss 0.430723 trained in 2.1 seconds
# * Step not_so_random will try to check up to 63 models
# 16_LightGBM logloss 0.400817 trained in 1.26 seconds
# 7_Xgboost logloss 0.42311 trained in 2.34 seconds
# 25_CatBoost logloss 0.401414 trained in 1.65 seconds
# 34_RandomForest logloss 0.402119 trained in 2.92 seconds
# 43_ExtraTrees logloss 0.382738 trained in 2.39 seconds
# Skip golden_features because of the time limit.
# * Step kmeans_features will try to check up to 3 models
# 43_ExtraTrees_KMeansFeatures logloss 0.401354 trained in 2.7 seconds
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 22.0 seconds
# Please increase total_time_limit to at least (277 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 13 models
# 44_ExtraTrees logloss 0.381467 trained in 2.43 seconds
# 45_DecisionTree logloss 0.395102 trained in 1.12 seconds
# 46_LightGBM logloss 0.412151 trained in 1.53 seconds
# * Step hill_climbing_2 will try to check up to 14 models
# 47_DecisionTree logloss 0.395102 trained in 1.23 seconds
# 48_DecisionTree logloss 0.625035 trained in 1.53 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble logloss 0.365853 trained in 2.23 seconds
# AutoML fit time: 67.88 seconds
# AutoML best model: Ensemble
# CPU times: user 1min 37s, sys: 34.4 s, total: 2min 12s
# Wall time: 1min 11s
# AutoML(mode='Compete', total_time_limit=60)

# %%
# Evaluation
y_pred = automl.predict(X_train)
evaluate_model("mljar", y_train, y_pred)
# Out:
# Accuracy : 0.8418
# Precision: 0.8551
# Recall   : 0.7076
# F1-score : 0.7744

# %%
# Submission
create_submission(automl.predict, X_test, submission, "submission-mljar.csv")

# %%
# Results
pd.DataFrame(experiment).T.style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_a8d05_row0_col0, #T_a8d05_row0_col1, #T_a8d05_row0_col2, #T_a8d05_row0_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a8d05_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Acc</th>
#       <th class="col_heading level0 col1" >Pre</th>
#       <th class="col_heading level0 col2" >Rec</th>
#       <th class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8d05_level0_row0" class="row_heading level0 row0" >lazypredict</th>
#       <td id="T_a8d05_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_a8d05_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_a8d05_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_a8d05_row0_col3" class="data row0 col3" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_a8d05_level0_row1" class="row_heading level0 row1" >tpot</th>
#       <td id="T_a8d05_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_a8d05_row1_col1" class="data row1 col1" >0.89</td>
#       <td id="T_a8d05_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_a8d05_row1_col3" class="data row1 col3" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_a8d05_level0_row2" class="row_heading level0 row2" >mljar</th>
#       <td id="T_a8d05_row2_col0" class="data row2 col0" >0.84</td>
#       <td id="T_a8d05_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_a8d05_row2_col2" class="data row2 col2" >0.71</td>
#       <td id="T_a8d05_row2_col3" class="data row2 col3" >0.77</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to install and use
# * **Good** - It presents nice results
# * **Simple** - Many of the models are Tree-based
# * **Simple** - It runs the scikit-learn models
#
# Features
# * **Good** - It includes preprocessing, model trainning and finetunning
# * **Good** - It contains explainability features
#
# Public Score - 0.78229 (good)

# %% [markdown]
# <a id="automl-flaml"></a>
#
# ---
# # FLAML
#
# - [GitHub](https://github.com/microsoft/FLAML)
# - [Documentation](https://microsoft.github.io/FLAML/)
#
# **FLAML** is a library that finds accurate machine learning models automatically. It frees users from selecting learners and hyperparameters for each learner. It can also be used to tune generic hyperparameters for MLOps workflows, pipelines, mathematical/statistical models, algorithms, computing experiments, software configurations and so on. It contains many features as **MLJAR**, without explainability.
#
# [> Back to Table of Contents](#ToC)

# %%
# %%capture
# install FLAML
# !pip install flaml[notebook]==1.0.12

# %%
# %%time
from flaml import AutoML

automl = AutoML()
automl.fit(X_train, y_train, max_iter=500,
           task="classification", metric="micro_f1")
# Out:
# [flaml.automl: 10-10 18:23:57] {2600} INFO - task = classification
# [flaml.automl: 10-10 18:23:57] {2602} INFO - Data split method: stratified
# [flaml.automl: 10-10 18:23:57] {2605} INFO - Evaluation method: holdout
# [flaml.automl: 10-10 18:23:57] {2727} INFO - Minimizing error metric: 1-micro_f1
# [flaml.automl: 10-10 18:23:57] {2869} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'catboost', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl: 10-10 18:23:57] {3174} INFO - iteration 0, current learner lgbm
# [flaml.automl: 10-10 18:23:57] {3308} INFO - Estimated sufficient time budget=934s. Estimated necessary time budget=23s.
# [flaml.automl: 10-10 18:23:57] {3360} INFO -  at 0.1s,	estimator lgbm's best error=0.2418,	best estimator lgbm's best error=0.2418
# [flaml.automl: 10-10 18:23:57] {3174} INFO - iteration 1, current learner lgbm
# [flaml.automl: 10-10 18:23:57] {3360} INFO -  at 0.2s,	estimator lgbm's best error=0.2418,	best estimator lgbm's best error=0.2418
# [flaml.automl: 10-10 18:23:57] {3174} INFO - iteration 2, current learner lgbm
# [flaml.automl: 10-10 18:23:57] {3360} INFO -  at 0.2s,	estimator lgbm's best error=0.2418,	best estimator lgbm's best error=0.2418
# [flaml.automl: 10-10 18:23:57] {3174} INFO - iteration 3, current learner lgbm
# [flaml.automl: 10-10 18:23:57] {3360} INFO -  at 0.2s,	estimator lgbm's best error=0.2418,	best estimator lgbm's best error=0.2418
# [flaml.automl: 10-10 18:23:57] {3174} INFO - iteration 4, current learner lgbm
# [flaml.automl: 10-10 18:23:57] {3360} INFO -  at 0.3s,	estimator lgbm's best error=0.2418,	best estimator lgbm's best error=0.2418
# [flaml.automl: 10-10 18:23:57] {3174} INFO - iteration 5, current learner lgbm
# [flaml.automl: 10-10 18:23:57] {3360} INFO -  at 0.4s,	estimator lgbm's best error=0.2308,	best estimator lgbm's best error=0.2308
# [flaml.automl: 10-10 18:23:57] {3174} INFO - iteration 6, current learner xgboost
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 0.9s,	estimator xgboost's best error=0.2967,	best estimator lgbm's best error=0.2308
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 7, current learner extra_tree
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 1.2s,	estimator extra_tree's best error=0.2637,	best estimator lgbm's best error=0.2308
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 8, current learner rf
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 1.5s,	estimator rf's best error=0.2308,	best estimator lgbm's best error=0.2308
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 9, current learner lgbm
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 1.6s,	estimator lgbm's best error=0.2308,	best estimator lgbm's best error=0.2308
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 10, current learner lgbm
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 1.6s,	estimator lgbm's best error=0.2198,	best estimator lgbm's best error=0.2198
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 11, current learner lgbm
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 1.6s,	estimator lgbm's best error=0.2198,	best estimator lgbm's best error=0.2198
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 12, current learner lgbm
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 1.6s,	estimator lgbm's best error=0.2198,	best estimator lgbm's best error=0.2198
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 13, current learner lgbm
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 1.6s,	estimator lgbm's best error=0.2088,	best estimator lgbm's best error=0.2088
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 14, current learner lgbm
# [flaml.automl: 10-10 18:23:58] {3360} INFO -  at 1.7s,	estimator lgbm's best error=0.2088,	best estimator lgbm's best error=0.2088
# [flaml.automl: 10-10 18:23:58] {3174} INFO - iteration 15, current learner rf
# [flaml.automl: 10-10 18:23:59] {3360} INFO -  at 2.0s,	estimator rf's best error=0.2308,	best estimator lgbm's best error=0.2088
# [flaml.automl: 10-10 18:23:59] {3174} INFO - iteration 16, current learner lgbm
# [flaml.automl: 10-10 18:23:59] {3360} INFO -  at 2.1s,	estimator lgbm's best error=0.2088,	best estimator lgbm's best error=0.2088
# [flaml.automl: 10-10 18:23:59] {3174} INFO - iteration 17, current learner extra_tree
# [flaml.automl: 10-10 18:23:59] {3360} INFO -  at 2.4s,	estimator extra_tree's best error=0.2198,	best estimator lgbm's best error=0.2088
# [flaml.automl: 10-10 18:23:59] {3174} INFO - iteration 18, current learner lgbm
# [flaml.automl: 10-10 18:23:59] {3360} INFO -  at 2.4s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:23:59] {3174} INFO - iteration 19, current learner rf
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 2.7s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 20, current learner lgbm
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 2.8s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 21, current learner lgbm
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 2.8s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 22, current learner lgbm
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 2.8s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 23, current learner lgbm
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 2.9s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 24, current learner xgboost
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 2.9s,	estimator xgboost's best error=0.2637,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 25, current learner extra_tree
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 3.3s,	estimator extra_tree's best error=0.2198,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 26, current learner lgbm
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 3.3s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 27, current learner xgboost
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 3.4s,	estimator xgboost's best error=0.2418,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 28, current learner xgboost
# [flaml.automl: 10-10 18:24:00] {3360} INFO -  at 3.5s,	estimator xgboost's best error=0.2308,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:00] {3174} INFO - iteration 29, current learner extra_tree
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 3.9s,	estimator extra_tree's best error=0.2198,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 30, current learner lgbm
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 3.9s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 31, current learner lgbm
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 4.0s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 32, current learner lgbm
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 4.0s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 33, current learner xgboost
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 4.1s,	estimator xgboost's best error=0.2308,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 34, current learner lgbm
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 4.1s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 35, current learner lgbm
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 4.1s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 36, current learner extra_tree
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 4.5s,	estimator extra_tree's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 37, current learner lgbm
# [flaml.automl: 10-10 18:24:01] {3360} INFO -  at 4.5s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:01] {3174} INFO - iteration 38, current learner rf
# [flaml.automl: 10-10 18:24:02] {3360} INFO -  at 4.9s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:02] {3174} INFO - iteration 39, current learner lgbm
# [flaml.automl: 10-10 18:24:02] {3360} INFO -  at 5.0s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:02] {3174} INFO - iteration 40, current learner rf
# [flaml.automl: 10-10 18:24:02] {3360} INFO -  at 5.3s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:02] {3174} INFO - iteration 41, current learner xgboost
# [flaml.automl: 10-10 18:24:02] {3360} INFO -  at 5.4s,	estimator xgboost's best error=0.2308,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:02] {3174} INFO - iteration 42, current learner lgbm
# [flaml.automl: 10-10 18:24:02] {3360} INFO -  at 5.4s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:02] {3174} INFO - iteration 43, current learner rf
# [flaml.automl: 10-10 18:24:03] {3360} INFO -  at 5.8s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:03] {3174} INFO - iteration 44, current learner extra_tree
# [flaml.automl: 10-10 18:24:03] {3360} INFO -  at 6.3s,	estimator extra_tree's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:03] {3174} INFO - iteration 45, current learner rf
# [flaml.automl: 10-10 18:24:03] {3360} INFO -  at 6.6s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:03] {3174} INFO - iteration 46, current learner lgbm
# [flaml.automl: 10-10 18:24:03] {3360} INFO -  at 6.7s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:03] {3174} INFO - iteration 47, current learner xgboost
# [flaml.automl: 10-10 18:24:03] {3360} INFO -  at 6.7s,	estimator xgboost's best error=0.2308,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:03] {3174} INFO - iteration 48, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 6.8s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 49, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 6.8s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 50, current learner xgboost
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 6.9s,	estimator xgboost's best error=0.2198,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 51, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 6.9s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 52, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 6.9s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 53, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 6.9s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 54, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 7.0s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 55, current learner rf
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 7.4s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 56, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 7.5s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 57, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 7.5s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 58, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 7.5s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 59, current learner lgbm
# [flaml.automl: 10-10 18:24:04] {3360} INFO -  at 7.6s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:04] {3174} INFO - iteration 60, current learner rf
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 7.9s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 61, current learner lgbm
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 7.9s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 62, current learner rf
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 8.4s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 63, current learner xgboost
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 8.5s,	estimator xgboost's best error=0.2198,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 64, current learner lgbm
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 8.5s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 65, current learner lgbm
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 8.5s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 66, current learner xgboost
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 8.6s,	estimator xgboost's best error=0.2198,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 67, current learner lgbm
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 8.6s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 68, current learner lgbm
# [flaml.automl: 10-10 18:24:05] {3360} INFO -  at 8.7s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:05] {3174} INFO - iteration 69, current learner rf
# [flaml.automl: 10-10 18:24:06] {3360} INFO -  at 9.0s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:06] {3174} INFO - iteration 70, current learner xgboost
# [flaml.automl: 10-10 18:24:06] {3360} INFO -  at 9.1s,	estimator xgboost's best error=0.2198,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:06] {3174} INFO - iteration 71, current learner lgbm
# [flaml.automl: 10-10 18:24:06] {3360} INFO -  at 9.1s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:06] {3174} INFO - iteration 72, current learner extra_tree
# [flaml.automl: 10-10 18:24:06] {3360} INFO -  at 9.5s,	estimator extra_tree's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:06] {3174} INFO - iteration 73, current learner rf
# [flaml.automl: 10-10 18:24:07] {3360} INFO -  at 9.8s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:07] {3174} INFO - iteration 74, current learner extra_tree
# [flaml.automl: 10-10 18:24:07] {3360} INFO -  at 10.2s,	estimator extra_tree's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:07] {3174} INFO - iteration 75, current learner lgbm
# [flaml.automl: 10-10 18:24:07] {3360} INFO -  at 10.3s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:07] {3174} INFO - iteration 76, current learner lgbm
# [flaml.automl: 10-10 18:24:07] {3360} INFO -  at 10.3s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:07] {3174} INFO - iteration 77, current learner xgboost
# [flaml.automl: 10-10 18:24:07] {3360} INFO -  at 10.4s,	estimator xgboost's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:07] {3174} INFO - iteration 78, current learner rf
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 10.8s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 79, current learner lgbm
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 10.9s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 80, current learner xgboost
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.0s,	estimator xgboost's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 81, current learner lgbm
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.0s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 82, current learner xgboost
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.1s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 83, current learner xgboost
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.2s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 84, current learner xgboost
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.2s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 85, current learner xgboost
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.4s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 86, current learner xgboost
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.5s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 87, current learner xgboost
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.6s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 88, current learner lgbm
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.6s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 89, current learner xgboost
# [flaml.automl: 10-10 18:24:08] {3360} INFO -  at 11.7s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:08] {3174} INFO - iteration 90, current learner xgboost
# [flaml.automl: 10-10 18:24:09] {3360} INFO -  at 11.8s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:09] {3174} INFO - iteration 91, current learner extra_tree
# [flaml.automl: 10-10 18:24:09] {3360} INFO -  at 12.1s,	estimator extra_tree's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:09] {3174} INFO - iteration 92, current learner xgboost
# [flaml.automl: 10-10 18:24:09] {3360} INFO -  at 12.2s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:09] {3174} INFO - iteration 93, current learner xgboost
# [flaml.automl: 10-10 18:24:09] {3360} INFO -  at 12.3s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:09] {3174} INFO - iteration 94, current learner lgbm
# [flaml.automl: 10-10 18:24:09] {3360} INFO -  at 12.3s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:09] {3174} INFO - iteration 95, current learner extra_tree
# [flaml.automl: 10-10 18:24:09] {3360} INFO -  at 12.7s,	estimator extra_tree's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:09] {3174} INFO - iteration 96, current learner rf
# [flaml.automl: 10-10 18:24:10] {3360} INFO -  at 13.1s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:10] {3174} INFO - iteration 97, current learner xgboost
# [flaml.automl: 10-10 18:24:10] {3360} INFO -  at 13.1s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:10] {3174} INFO - iteration 98, current learner rf
# [flaml.automl: 10-10 18:24:10] {3360} INFO -  at 13.6s,	estimator rf's best error=0.2088,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:10] {3174} INFO - iteration 99, current learner lgbm
# [flaml.automl: 10-10 18:24:10] {3360} INFO -  at 13.6s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:10] {3174} INFO - iteration 100, current learner xgboost
# [flaml.automl: 10-10 18:24:10] {3360} INFO -  at 13.7s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:10] {3174} INFO - iteration 101, current learner xgboost
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 13.8s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 102, current learner lgbm
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 13.8s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 103, current learner xgboost
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 13.9s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 104, current learner lgbm
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 13.9s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 105, current learner xgboost
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 14.0s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 106, current learner xgboost
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 14.1s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 107, current learner lgbm
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 14.1s,	estimator lgbm's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 108, current learner xgboost
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 14.2s,	estimator xgboost's best error=0.1978,	best estimator lgbm's best error=0.1978
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 109, current learner xgboost
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 14.3s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 110, current learner lgbm
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 14.3s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 111, current learner xgboost
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 14.4s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 112, current learner xgboost
# [flaml.automl: 10-10 18:24:11] {3360} INFO -  at 14.5s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:11] {3174} INFO - iteration 113, current learner extra_tree
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 14.8s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 114, current learner lgbm
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 14.9s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 115, current learner lgbm
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 14.9s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 116, current learner xgboost
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.0s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 117, current learner xgboost
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.1s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 118, current learner lgbm
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.2s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 119, current learner xgboost
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.3s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 120, current learner xgboost
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.4s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 121, current learner xgboost
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.5s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 122, current learner xgboost
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.6s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 123, current learner lgbm
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.6s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 124, current learner lgbm
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.6s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 125, current learner lgbm
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.7s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 126, current learner lgbm
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.7s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 127, current learner lgbm
# [flaml.automl: 10-10 18:24:12] {3360} INFO -  at 15.7s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:12] {3174} INFO - iteration 128, current learner xgboost
# [flaml.automl: 10-10 18:24:13] {3360} INFO -  at 15.8s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:13] {3174} INFO - iteration 129, current learner xgboost
# [flaml.automl: 10-10 18:24:13] {3360} INFO -  at 15.9s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:13] {3174} INFO - iteration 130, current learner xgboost
# [flaml.automl: 10-10 18:24:13] {3360} INFO -  at 16.0s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:13] {3174} INFO - iteration 131, current learner xgboost
# [flaml.automl: 10-10 18:24:13] {3360} INFO -  at 16.1s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:13] {3174} INFO - iteration 132, current learner lgbm
# [flaml.automl: 10-10 18:24:13] {3360} INFO -  at 16.1s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:13] {3174} INFO - iteration 133, current learner rf
# [flaml.automl: 10-10 18:24:13] {3360} INFO -  at 16.5s,	estimator rf's best error=0.2088,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:13] {3174} INFO - iteration 134, current learner xgboost
# [flaml.automl: 10-10 18:24:13] {3360} INFO -  at 16.5s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:13] {3174} INFO - iteration 135, current learner extra_tree
# [flaml.automl: 10-10 18:24:14] {3360} INFO -  at 16.9s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:14] {3174} INFO - iteration 136, current learner xgboost
# [flaml.automl: 10-10 18:24:14] {3360} INFO -  at 17.0s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:14] {3174} INFO - iteration 137, current learner lgbm
# [flaml.automl: 10-10 18:24:14] {3360} INFO -  at 17.0s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:14] {3174} INFO - iteration 138, current learner xgboost
# [flaml.automl: 10-10 18:24:14] {3360} INFO -  at 17.1s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:14] {3174} INFO - iteration 139, current learner catboost
# [flaml.automl: 10-10 18:24:14] {3360} INFO -  at 17.3s,	estimator catboost's best error=0.2418,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:14] {3174} INFO - iteration 140, current learner catboost
# [flaml.automl: 10-10 18:24:14] {3360} INFO -  at 17.6s,	estimator catboost's best error=0.2418,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:14] {3174} INFO - iteration 141, current learner catboost
# [flaml.automl: 10-10 18:24:15] {3360} INFO -  at 17.8s,	estimator catboost's best error=0.2418,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:15] {3174} INFO - iteration 142, current learner catboost
# [flaml.automl: 10-10 18:24:15] {3360} INFO -  at 18.0s,	estimator catboost's best error=0.2308,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:15] {3174} INFO - iteration 143, current learner xgboost
# [flaml.automl: 10-10 18:24:15] {3360} INFO -  at 18.1s,	estimator xgboost's best error=0.1868,	best estimator xgboost's best error=0.1868
# [flaml.automl: 10-10 18:24:15] {3174} INFO - iteration 144, current learner xgboost
# [flaml.automl: 10-10 18:24:15] {3360} INFO -  at 18.2s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:15] {3174} INFO - iteration 145, current learner xgboost
# [flaml.automl: 10-10 18:24:15] {3360} INFO -  at 18.2s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:15] {3174} INFO - iteration 146, current learner rf
# [flaml.automl: 10-10 18:24:15] {3360} INFO -  at 18.7s,	estimator rf's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:15] {3174} INFO - iteration 147, current learner lgbm
# [flaml.automl: 10-10 18:24:15] {3360} INFO -  at 18.7s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:15] {3174} INFO - iteration 148, current learner rf
# [flaml.automl: 10-10 18:24:16] {3360} INFO -  at 19.1s,	estimator rf's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:16] {3174} INFO - iteration 149, current learner lgbm
# [flaml.automl: 10-10 18:24:16] {3360} INFO -  at 19.1s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:16] {3174} INFO - iteration 150, current learner lgbm
# [flaml.automl: 10-10 18:24:16] {3360} INFO -  at 19.1s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:16] {3174} INFO - iteration 151, current learner catboost
# [flaml.automl: 10-10 18:24:16] {3360} INFO -  at 19.4s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:16] {3174} INFO - iteration 152, current learner xgboost
# [flaml.automl: 10-10 18:24:16] {3360} INFO -  at 19.5s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:16] {3174} INFO - iteration 153, current learner xgboost
# [flaml.automl: 10-10 18:24:16] {3360} INFO -  at 19.6s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:16] {3174} INFO - iteration 154, current learner lgbm
# [flaml.automl: 10-10 18:24:16] {3360} INFO -  at 19.6s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:16] {3174} INFO - iteration 155, current learner lgbm
# [flaml.automl: 10-10 18:24:16] {3360} INFO -  at 19.7s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:16] {3174} INFO - iteration 156, current learner xgboost
# [flaml.automl: 10-10 18:24:17] {3360} INFO -  at 19.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:17] {3174} INFO - iteration 157, current learner xgboost
# [flaml.automl: 10-10 18:24:17] {3360} INFO -  at 19.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:17] {3174} INFO - iteration 158, current learner catboost
# [flaml.automl: 10-10 18:24:17] {3360} INFO -  at 20.3s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:17] {3174} INFO - iteration 159, current learner catboost
# [flaml.automl: 10-10 18:24:17] {3360} INFO -  at 20.5s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:17] {3174} INFO - iteration 160, current learner xgboost
# [flaml.automl: 10-10 18:24:17] {3360} INFO -  at 20.6s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:17] {3174} INFO - iteration 161, current learner catboost
# [flaml.automl: 10-10 18:24:18] {3360} INFO -  at 21.0s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:18] {3174} INFO - iteration 162, current learner xgboost
# [flaml.automl: 10-10 18:24:18] {3360} INFO -  at 21.0s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:18] {3174} INFO - iteration 163, current learner extra_tree
# [flaml.automl: 10-10 18:24:18] {3360} INFO -  at 21.5s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:18] {3174} INFO - iteration 164, current learner xgboost
# [flaml.automl: 10-10 18:24:18] {3360} INFO -  at 21.6s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:18] {3174} INFO - iteration 165, current learner catboost
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 21.8s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 166, current learner xgboost
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 21.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 167, current learner xgboost
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 21.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 168, current learner xgboost
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 22.0s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 169, current learner rf
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 22.5s,	estimator rf's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 170, current learner lgbm
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 22.5s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 171, current learner lgbm
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 22.5s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 172, current learner xgboost
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 22.6s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 173, current learner xgboost
# [flaml.automl: 10-10 18:24:19] {3360} INFO -  at 22.7s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:19] {3174} INFO - iteration 174, current learner xgboost
# [flaml.automl: 10-10 18:24:20] {3360} INFO -  at 22.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:20] {3174} INFO - iteration 175, current learner xgboost
# [flaml.automl: 10-10 18:24:20] {3360} INFO -  at 22.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:20] {3174} INFO - iteration 176, current learner extra_tree
# [flaml.automl: 10-10 18:24:20] {3360} INFO -  at 23.2s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:20] {3174} INFO - iteration 177, current learner xgboost
# [flaml.automl: 10-10 18:24:20] {3360} INFO -  at 23.3s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:20] {3174} INFO - iteration 178, current learner xgboost
# [flaml.automl: 10-10 18:24:20] {3360} INFO -  at 23.4s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:20] {3174} INFO - iteration 179, current learner xgboost
# [flaml.automl: 10-10 18:24:20] {3360} INFO -  at 23.5s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:20] {3174} INFO - iteration 180, current learner xgboost
# [flaml.automl: 10-10 18:24:20] {3360} INFO -  at 23.6s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:20] {3174} INFO - iteration 181, current learner xgboost
# [flaml.automl: 10-10 18:24:20] {3360} INFO -  at 23.7s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:20] {3174} INFO - iteration 182, current learner xgboost
# [flaml.automl: 10-10 18:24:21] {3360} INFO -  at 23.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:21] {3174} INFO - iteration 183, current learner lgbm
# [flaml.automl: 10-10 18:24:21] {3360} INFO -  at 23.8s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:21] {3174} INFO - iteration 184, current learner xgboost
# [flaml.automl: 10-10 18:24:21] {3360} INFO -  at 23.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:21] {3174} INFO - iteration 185, current learner xgboost
# [flaml.automl: 10-10 18:24:21] {3360} INFO -  at 24.0s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:21] {3174} INFO - iteration 186, current learner catboost
# [flaml.automl: 10-10 18:24:21] {3360} INFO -  at 24.4s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:21] {3174} INFO - iteration 187, current learner xgboost
# [flaml.automl: 10-10 18:24:21] {3360} INFO -  at 24.5s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:21] {3174} INFO - iteration 188, current learner lgbm
# [flaml.automl: 10-10 18:24:21] {3360} INFO -  at 24.5s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:21] {3174} INFO - iteration 189, current learner catboost
# [flaml.automl: 10-10 18:24:22] {3360} INFO -  at 25.3s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:22] {3174} INFO - iteration 190, current learner xgboost
# [flaml.automl: 10-10 18:24:22] {3360} INFO -  at 25.4s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:22] {3174} INFO - iteration 191, current learner rf
# [flaml.automl: 10-10 18:24:22] {3360} INFO -  at 25.7s,	estimator rf's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:22] {3174} INFO - iteration 192, current learner xgboost
# [flaml.automl: 10-10 18:24:23] {3360} INFO -  at 25.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:23] {3174} INFO - iteration 193, current learner xgboost
# [flaml.automl: 10-10 18:24:23] {3360} INFO -  at 25.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:23] {3174} INFO - iteration 194, current learner xgboost
# [flaml.automl: 10-10 18:24:23] {3360} INFO -  at 25.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:23] {3174} INFO - iteration 195, current learner catboost
# [flaml.automl: 10-10 18:24:23] {3360} INFO -  at 26.5s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:23] {3174} INFO - iteration 196, current learner lgbm
# [flaml.automl: 10-10 18:24:23] {3360} INFO -  at 26.5s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:23] {3174} INFO - iteration 197, current learner xgboost
# [flaml.automl: 10-10 18:24:23] {3360} INFO -  at 26.6s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:23] {3174} INFO - iteration 198, current learner xgboost
# [flaml.automl: 10-10 18:24:23] {3360} INFO -  at 26.7s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:23] {3174} INFO - iteration 199, current learner xgboost
# [flaml.automl: 10-10 18:24:24] {3360} INFO -  at 26.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:24] {3174} INFO - iteration 200, current learner xgboost
# [flaml.automl: 10-10 18:24:24] {3360} INFO -  at 26.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:24] {3174} INFO - iteration 201, current learner lgbm
# [flaml.automl: 10-10 18:24:24] {3360} INFO -  at 26.9s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:24] {3174} INFO - iteration 202, current learner catboost
# [flaml.automl: 10-10 18:24:24] {3360} INFO -  at 27.1s,	estimator catboost's best error=0.2198,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:24] {3174} INFO - iteration 203, current learner xgboost
# [flaml.automl: 10-10 18:24:24] {3360} INFO -  at 27.2s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:24] {3174} INFO - iteration 204, current learner xgboost
# [flaml.automl: 10-10 18:24:24] {3360} INFO -  at 27.3s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:24] {3174} INFO - iteration 205, current learner extra_tree
# [flaml.automl: 10-10 18:24:24] {3360} INFO -  at 27.7s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:24] {3174} INFO - iteration 206, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 27.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 207, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 27.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 208, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 28.0s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 209, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 28.1s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 210, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 28.2s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 211, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 28.3s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 212, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 28.3s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 213, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 28.4s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 214, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 28.5s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 215, current learner xgboost
# [flaml.automl: 10-10 18:24:25] {3360} INFO -  at 28.6s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:25] {3174} INFO - iteration 216, current learner extra_tree
# [flaml.automl: 10-10 18:24:26] {3360} INFO -  at 28.9s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:26] {3174} INFO - iteration 217, current learner lgbm
# [flaml.automl: 10-10 18:24:26] {3360} INFO -  at 28.9s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:26] {3174} INFO - iteration 218, current learner lgbm
# ...
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 434, current learner xgboost
# [flaml.automl: 10-10 18:24:54] {3360} INFO -  at 56.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 435, current learner xgboost
# [flaml.automl: 10-10 18:24:54] {3360} INFO -  at 57.0s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 436, current learner xgboost
# [flaml.automl: 10-10 18:24:54] {3360} INFO -  at 57.1s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 437, current learner xgboost
# [flaml.automl: 10-10 18:24:54] {3360} INFO -  at 57.1s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 438, current learner xgboost
# [flaml.automl: 10-10 18:24:54] {3360} INFO -  at 57.2s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 439, current learner xgboost
# [flaml.automl: 10-10 18:24:54] {3360} INFO -  at 57.3s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 440, current learner extra_tree
# [flaml.automl: 10-10 18:24:54] {3360} INFO -  at 57.7s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 441, current learner xgboost
# [flaml.automl: 10-10 18:24:54] {3360} INFO -  at 57.7s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:54] {3174} INFO - iteration 442, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 57.8s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 443, current learner lgbm
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 57.8s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 444, current learner extra_tree
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 58.2s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 445, current learner lgbm
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 58.2s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 446, current learner xgboost
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 58.3s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 447, current learner lgbm
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 58.3s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 448, current learner xgboost
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 58.4s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 449, current learner lgbm
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 58.5s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 450, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 58.6s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 451, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:24:55] {3360} INFO -  at 58.7s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:55] {3174} INFO - iteration 452, current learner extra_tree
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.0s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 453, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.1s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 454, current learner lgbm
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.1s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 455, current learner lgbm
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.2s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 456, current learner lgbm
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.3s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 457, current learner xgboost
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.4s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 458, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.5s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 459, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.6s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 460, current learner xgboost
# [flaml.automl: 10-10 18:24:56] {3360} INFO -  at 59.7s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:56] {3174} INFO - iteration 461, current learner xgboost
# [flaml.automl: 10-10 18:24:57] {3360} INFO -  at 59.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:57] {3174} INFO - iteration 462, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:24:57] {3360} INFO -  at 59.9s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:57] {3174} INFO - iteration 463, current learner xgboost
# [flaml.automl: 10-10 18:24:57] {3360} INFO -  at 59.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:57] {3174} INFO - iteration 464, current learner rf
# [flaml.automl: 10-10 18:24:57] {3360} INFO -  at 60.3s,	estimator rf's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:57] {3174} INFO - iteration 465, current learner lgbm
# [flaml.automl: 10-10 18:24:57] {3360} INFO -  at 60.3s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:57] {3174} INFO - iteration 466, current learner lgbm
# [flaml.automl: 10-10 18:24:57] {3360} INFO -  at 60.3s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:57] {3174} INFO - iteration 467, current learner extra_tree
# [flaml.automl: 10-10 18:24:58] {3360} INFO -  at 60.8s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:58] {3174} INFO - iteration 468, current learner lgbm
# [flaml.automl: 10-10 18:24:58] {3360} INFO -  at 60.8s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:58] {3174} INFO - iteration 469, current learner rf
# [flaml.automl: 10-10 18:24:58] {3360} INFO -  at 61.2s,	estimator rf's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:58] {3174} INFO - iteration 470, current learner extra_tree
# [flaml.automl: 10-10 18:24:58] {3360} INFO -  at 61.6s,	estimator extra_tree's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:58] {3174} INFO - iteration 471, current learner catboost
# [flaml.automl: 10-10 18:24:59] {3360} INFO -  at 61.8s,	estimator catboost's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:59] {3174} INFO - iteration 472, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:24:59] {3360} INFO -  at 61.9s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:59] {3174} INFO - iteration 473, current learner rf
# [flaml.automl: 10-10 18:24:59] {3360} INFO -  at 62.2s,	estimator rf's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:59] {3174} INFO - iteration 474, current learner xgboost
# [flaml.automl: 10-10 18:24:59] {3360} INFO -  at 62.3s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:59] {3174} INFO - iteration 475, current learner catboost
# [flaml.automl: 10-10 18:24:59] {3360} INFO -  at 62.6s,	estimator catboost's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:24:59] {3174} INFO - iteration 476, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:25:00] {3360} INFO -  at 63.1s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:00] {3174} INFO - iteration 477, current learner catboost
# [flaml.automl: 10-10 18:25:00] {3360} INFO -  at 63.4s,	estimator catboost's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:00] {3174} INFO - iteration 478, current learner xgboost
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 63.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 479, current learner xgboost
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 63.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 480, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 64.0s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 481, current learner lgbm
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 64.1s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 482, current learner xgboost
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 64.1s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 483, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 64.2s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 484, current learner lgbm
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 64.2s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 485, current learner xgboost
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 64.3s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 486, current learner catboost
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 64.7s,	estimator catboost's best error=0.2088,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 487, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:25:01] {3360} INFO -  at 64.7s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:01] {3174} INFO - iteration 488, current learner xgboost
# [flaml.automl: 10-10 18:25:02] {3360} INFO -  at 64.8s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:02] {3174} INFO - iteration 489, current learner xgboost
# [flaml.automl: 10-10 18:25:02] {3360} INFO -  at 64.9s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:02] {3174} INFO - iteration 490, current learner xgboost
# [flaml.automl: 10-10 18:25:02] {3360} INFO -  at 65.0s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:02] {3174} INFO - iteration 491, current learner xgboost
# [flaml.automl: 10-10 18:25:02] {3360} INFO -  at 65.0s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:02] {3174} INFO - iteration 492, current learner rf
# [flaml.automl: 10-10 18:25:02] {3360} INFO -  at 65.5s,	estimator rf's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:02] {3174} INFO - iteration 493, current learner lgbm
# [flaml.automl: 10-10 18:25:02] {3360} INFO -  at 65.5s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:02] {3174} INFO - iteration 494, current learner xgboost
# [flaml.automl: 10-10 18:25:02] {3360} INFO -  at 65.6s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:02] {3174} INFO - iteration 495, current learner rf
# [flaml.automl: 10-10 18:25:03] {3360} INFO -  at 65.9s,	estimator rf's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:03] {3174} INFO - iteration 496, current learner xgboost
# [flaml.automl: 10-10 18:25:03] {3360} INFO -  at 66.0s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:03] {3174} INFO - iteration 497, current learner xgb_limitdepth
# [flaml.automl: 10-10 18:25:03] {3360} INFO -  at 66.1s,	estimator xgb_limitdepth's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:03] {3174} INFO - iteration 498, current learner xgboost
# [flaml.automl: 10-10 18:25:03] {3360} INFO -  at 66.2s,	estimator xgboost's best error=0.1648,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:03] {3174} INFO - iteration 499, current learner lgbm
# [flaml.automl: 10-10 18:25:03] {3360} INFO -  at 66.2s,	estimator lgbm's best error=0.1978,	best estimator xgboost's best error=0.1648
# [flaml.automl: 10-10 18:25:03] {3620} INFO - retrain xgboost for 0.1s
# [flaml.automl: 10-10 18:25:03] {3625} INFO - retrained model: XGBClassifier(base_score=0.5, booster='gbtree', callbacks=[],
#               colsample_bylevel=1.0, colsample_bynode=1, colsample_bytree=1.0,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='lossguide',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.7895542070824232, max_bin=256,
#               max_cat_to_onehot=4, max_delta_step=0, max_depth=0, max_leaves=15,
#               min_child_weight=7.110058659500221, missing=nan,
#               monotone_constraints='()', n_estimators=6, n_jobs=-1,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0.05626297533035684, reg_lambda=10.184858367611008, ...)
# [flaml.automl: 10-10 18:25:03] {2900} INFO - fit succeeded
# [flaml.automl: 10-10 18:25:03] {2902} INFO - Time taken to find the best model: 18.150034189224243
# CPU times: user 1min 38s, sys: 5.77 s, total: 1min 44s
# Wall time: 1min 7s

# %%
# Best model
print(automl.model.estimator)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=[],
#               colsample_bylevel=1.0, colsample_bynode=1, colsample_bytree=1.0,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='lossguide',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.7895542070824232, max_bin=256,
#               max_cat_to_onehot=4, max_delta_step=0, max_depth=0, max_leaves=15,
#               min_child_weight=7.110058659500221, missing=nan,
#               monotone_constraints='()', n_estimators=6, n_jobs=-1,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0.05626297533035684, reg_lambda=10.184858367611008, ...)

# %%
# Evaluation
y_pred = automl.predict(X_train)
evaluate_model("flaml", y_train, y_pred)
# Out:
# Accuracy : 0.8530
# Precision: 0.8482
# Recall   : 0.7515
# F1-score : 0.7969

# %%
# Submission
create_submission(automl.predict, X_test, submission, "submission-flaml.csv")

# %%
# Results
pd.DataFrame(experiment).T.style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_f7c47_row0_col0, #T_f7c47_row0_col1, #T_f7c47_row0_col2, #T_f7c47_row0_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f7c47_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Acc</th>
#       <th class="col_heading level0 col1" >Pre</th>
#       <th class="col_heading level0 col2" >Rec</th>
#       <th class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7c47_level0_row0" class="row_heading level0 row0" >lazypredict</th>
#       <td id="T_f7c47_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_f7c47_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_f7c47_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_f7c47_row0_col3" class="data row0 col3" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_f7c47_level0_row1" class="row_heading level0 row1" >tpot</th>
#       <td id="T_f7c47_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_f7c47_row1_col1" class="data row1 col1" >0.89</td>
#       <td id="T_f7c47_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_f7c47_row1_col3" class="data row1 col3" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_f7c47_level0_row2" class="row_heading level0 row2" >mljar</th>
#       <td id="T_f7c47_row2_col0" class="data row2 col0" >0.84</td>
#       <td id="T_f7c47_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_f7c47_row2_col2" class="data row2 col2" >0.71</td>
#       <td id="T_f7c47_row2_col3" class="data row2 col3" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_f7c47_level0_row3" class="row_heading level0 row3" >flaml</th>
#       <td id="T_f7c47_row3_col0" class="data row3 col0" >0.85</td>
#       <td id="T_f7c47_row3_col1" class="data row3 col1" >0.85</td>
#       <td id="T_f7c47_row3_col2" class="data row3 col2" >0.75</td>
#       <td id="T_f7c47_row3_col3" class="data row3 col3" >0.80</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to install and use
# * **Good** - It presents nice results
# * **Bad** - Only contains a few models
# * **Interesting** - It has a version for .NET
#
# Features
# * **Good** - It includes preprocessing, model trainning and finetunning
# * **Good** - It contains text processing and online learning
#
# Public Score - 0.78468 (best)

# %% [markdown]
# <a id="automl-autogluon"></a>
#
# ---
# # AutoGluon
#
# - [GitHub](https://github.com/awslabs/autogluon)
# - [Documentation](https://auto.gluon.ai/)
#
# **AutoGluon** automates machine learning tasks enabling you to easily achieve strong predictive performance in your applications. With just a few lines of code, you can train and deploy high-accuracy machine learning and deep learning models on image, text, time series, and tabular data. _It is the most robust and generic AutoML tool so far_.
#
# [> Back to Table of Contents](#ToC)

# %%
# %%capture
# install AutoGluon
# !pip install autogluon==0.5.2

# %%
# %%time
from autogluon.tabular import TabularPredictor

automl = TabularPredictor(label=label_column, path="titanic-autogluon",
                           eval_metric="f1_micro", verbosity=1)
automl.fit(train.drop(columns=['PassengerId']))
# Out:
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# AutoGluon will gauge predictive performance using evaluation metric: 'f1_micro'
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# 	Warning: Exception caused XGBoost to fail during training... Skipping this model.
# 		2 different `eval_metric` are provided.  Use the one in constructor or `set_params` instead.
# Detailed Traceback:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1126, in _train_and_save
#     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1083, in _train_single
#     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/autogluon/core/models/abstract/abstract_model.py", line 587, in fit
#     out = self._fit(**kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/autogluon/tabular/models/xgboost/xgboost_model.py", line 143, in _fit
#     sample_weight=sample_weight
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/core.py", line 532, in inner_f
#     self.silent = silent
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py", line 1380, in fit
#     ''')
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py", line 810, in _configure_fit
#     Returns
#   File "/opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py", line 802, in _duplicated
#     Margin added to prediction.
# ValueError: 2 different `eval_metric` are provided.  Use the one in constructor or `set_params` instead.
# CPU times: user 32.3 s, sys: 1.86 s, total: 34.1 s
# Wall time: 24.5 s

# %%
# Generates a complete report about the models
_ = automl.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0        NeuralNetTorch       0.85           0.02      4.24                    0.02               4.24            1       True         11
# 1   WeightedEnsemble_L2       0.85           0.03      5.59                    0.00               1.34            2       True         13
# 2       NeuralNetFastAI       0.84           0.04      1.93                    0.04               1.93            1       True         10
# 3         LightGBMLarge       0.83           0.01      2.64                    0.01               2.64            1       True         12
# 4              LightGBM       0.82           0.01      2.05                    0.01               2.05            1       True          4
# 5      RandomForestGini       0.82           0.21      1.17                    0.21               1.17            1       True          5
# 6            LightGBMXT       0.82           0.01      2.84                    0.01               2.84            1       True          3
# 7      RandomForestEntr       0.82           0.11      1.17                    0.11               1.17            1       True          6
# 8              CatBoost       0.81           0.01      1.41                    0.01               1.41            1       True          7
# 9        ExtraTreesEntr       0.80           0.11      1.08                    0.11               1.08            1       True          9
# 10       ExtraTreesGini       0.80           0.21      1.07                    0.21               1.07            1       True          8
# 11       KNeighborsUnif       0.72           0.03      0.78                    0.03               0.78            1       True          1
# 12       KNeighborsDist       0.70           0.01      0.01                    0.01               0.01            1       True          2
# Number of models trained: 13
# Types of models trained:
# {'RFModel', 'TabularNeuralNetTorchModel', 'CatBoostModel', 'NNFastAiTabularModel', 'XTModel', 'KNNModel', 'WeightedEnsembleModel', 'LGBModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])                    : 2 | ['Ticket', 'Cabin']
# ('float', [])                       : 6 | ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', ...]
# ('int', ['binned', 'text_special']) : 9 | ['Name.char_count', 'Name.word_count', 'Name.capital_ratio', 'Name.lower_ratio', 'Name.special_ratio', ...]
# ('int', ['bool'])                   : 1 | ['Sex']
# ('int', ['text_ngram'])             : 9 | ['__nlp__.henry', '__nlp__.john', '__nlp__.master', '__nlp__.miss', '__nlp__.mr', ...]
# Plot summary of models saved to file: titanic-autogluon/SummaryOfModels.html
# *** End of fit() summary ***

# %%
# Evaluation
y_pred = automl.predict(train.drop(columns=['PassengerId']))
evaluate_model("auto-gluon", y_train, y_pred)
# Out:
# Accuracy : 0.9012
# Precision: 0.8969
# Recall   : 0.8392
# F1-score : 0.8671

# %%
# Submission
create_submission(automl.predict, test.drop(columns=['PassengerId']), submission, "submission-auto-gluon.csv")

# %%
# Results
pd.DataFrame(experiment).T.style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_a79f6_row0_col0, #T_a79f6_row0_col1, #T_a79f6_row0_col2, #T_a79f6_row0_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a79f6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Acc</th>
#       <th class="col_heading level0 col1" >Pre</th>
#       <th class="col_heading level0 col2" >Rec</th>
#       <th class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a79f6_level0_row0" class="row_heading level0 row0" >lazypredict</th>
#       <td id="T_a79f6_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_a79f6_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_a79f6_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_a79f6_row0_col3" class="data row0 col3" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_a79f6_level0_row1" class="row_heading level0 row1" >tpot</th>
#       <td id="T_a79f6_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_a79f6_row1_col1" class="data row1 col1" >0.89</td>
#       <td id="T_a79f6_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_a79f6_row1_col3" class="data row1 col3" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_a79f6_level0_row2" class="row_heading level0 row2" >mljar</th>
#       <td id="T_a79f6_row2_col0" class="data row2 col0" >0.84</td>
#       <td id="T_a79f6_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_a79f6_row2_col2" class="data row2 col2" >0.71</td>
#       <td id="T_a79f6_row2_col3" class="data row2 col3" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_a79f6_level0_row3" class="row_heading level0 row3" >flaml</th>
#       <td id="T_a79f6_row3_col0" class="data row3 col0" >0.85</td>
#       <td id="T_a79f6_row3_col1" class="data row3 col1" >0.85</td>
#       <td id="T_a79f6_row3_col2" class="data row3 col2" >0.75</td>
#       <td id="T_a79f6_row3_col3" class="data row3 col3" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_a79f6_level0_row4" class="row_heading level0 row4" >auto-gluon</th>
#       <td id="T_a79f6_row4_col0" class="data row4 col0" >0.90</td>
#       <td id="T_a79f6_row4_col1" class="data row4 col1" >0.90</td>
#       <td id="T_a79f6_row4_col2" class="data row4 col2" >0.84</td>
#       <td id="T_a79f6_row4_col3" class="data row4 col3" >0.87</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to install and use
# * **Good** - It presents amazing results
#
# Features
# * **Good** - It includes preprocessing, model trainning and finetunning
# * **Good** - It contains text, image and multimodal processing techniques
#
# Public Score - 0.76076

# %% [markdown]
# <a id="automl-h2o"></a>
#
# ---
# # H2O
#
# - [GitHub](https://github.com/h2oai/h2o-3)
# - [Documentation](https://h2o.ai/)
#
# **H2O** is an in-memory platform for distributed, scalable machine learning. It provides implementations of many popular algorithms; it didn't use scikit-learn implementations, it contains its own implementations.
#
# [> Back to Table of Contents](#ToC)

# %%
# %%capture
# install H20
# !pip install h2o==3.36.1.4

# %%
# %%time
import h2o
from h2o.automl import H2OAutoML

# Start the H2O cluster (locally)
h2o.init()
# Get H2O data frame
hf_train = h2o.H2OFrame(train)
hf_test  = h2o.H2OFrame(test)
hf_train[label_column] = hf_train[label_column].asfactor()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.16" 2022-07-19; OpenJDK Runtime Environment (build 11.0.16+8-post-Ubuntu-0ubuntu120.04); OpenJDK 64-Bit Server VM (build 11.0.16+8-post-Ubuntu-0ubuntu120.04, mixed mode, sharing)
#   Starting server from /opt/conda/lib/python3.7/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpdwyktum7
#   JVM stdout: /tmp/tmpdwyktum7/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpdwyktum7/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.4
# H2O_cluster_version_age:    2 months and 7 days
# H2O_cluster_name:           H2O_from_python_unknownUser_oq2gwv
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    4 Gb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.7.12 final
# --------------------------  ----------------------------------
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# CPU times: user 258 ms, sys: 88.8 ms, total: 347 ms
# Wall time: 10.8 s

# %%
# AutoML for 10 base models
automl = H2OAutoML(max_models=10, seed=seed_number)
automl.train(x=x_columns, y=label_column, training_frame=hf_train)
# Out:
# AutoML progress: |███████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# =============
# H2OGradientBoostingEstimator :  Gradient Boosting Machine
# Model Key:  GBM_3_AutoML_1_20221010_182717
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0              40.00                     40.00             21023.00
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0       7.00       8.00        7.97       23.00       52.00        37.12
# ModelMetricsBinomial: gbm
# ** Reported on train data. **
#
# MSE: 0.07409565800317175
# RMSE: 0.2722051762975343
# LogLoss: 0.262592101090439
# Mean Per-Class Error: 0.09452593231713163
# AUC: 0.9640840869630055
# AUCPR: 0.9540204588442834
# Gini: 0.928168173926011
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.3457409995979469:
#               0      1   Error           Rate
# 0      0 503.00  46.00  0.0838   (46.0/549.0)
# 1      1  36.00 306.00  0.1053   (36.0/342.0)
# 2  Total 539.00 352.00   0.092   (82.0/891.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold  value    idx
# 0                        max f1       0.35   0.88 207.00
# 1                        max f2       0.29   0.90 224.00
# 2                  max f0point5       0.56   0.91 159.00
# 3                  max accuracy       0.50   0.91 171.00
# 4                 max precision       0.99   1.00   0.00
# 5                    max recall       0.07   1.00 356.00
# 6               max specificity       0.99   1.00   0.00
# 7              max absolute_mcc       0.50   0.81 171.00
# 8    max min_per_class_accuracy       0.33   0.90 214.00
# 9   max mean_per_class_accuracy       0.34   0.91 210.00
# 10                      max tns       0.99 549.00   0.00
# 11                      max fns       0.99 340.00   0.00
# 12                      max fps       0.01 549.00 399.00
# 13                      max tps       0.07 342.00 356.00
# 14                      max tnr       0.99   1.00   0.00
# 15                      max fnr       0.99   0.99   0.00
# 16                      max fpr       0.01   1.00 399.00
# 17                      max tpr       0.07   1.00 356.00
# Gains/Lift Table: Avg response rate: 38.38 %, avg score: 38.19 %
#     group  cumulative_data_fraction  lower_threshold  lift  cumulative_lift  \
# 0       1                      0.01             0.98  2.61             2.61
# 1       2                      0.02             0.98  2.61             2.61
# 2       3                      0.03             0.98  2.61             2.61
# 3       4                      0.04             0.97  2.61             2.61
# 4       5                      0.05             0.97  2.61             2.61
# 5       6                      0.10             0.94  2.61             2.61
# 6       7                      0.15             0.90  2.61             2.61
# 7       8                      0.20             0.84  2.61             2.61
# 8       9                      0.30             0.63  2.20             2.47
# 9      10                      0.40             0.34  1.58             2.25
# 10     11                      0.50             0.20  0.47             1.89
# 11     12                      0.60             0.13  0.32             1.63
# 12     13                      0.70             0.10  0.15             1.42
# 13     14                      0.80             0.08  0.03             1.24
# 14     15                      0.90             0.06  0.03             1.11
# 15     16                      1.00             0.01  0.00             1.00
#
#     response_rate  score  cumulative_response_rate  cumulative_score  \
# 0            1.00   0.98                      1.00              0.98
# 1            1.00   0.98                      1.00              0.98
# 2            1.00   0.98                      1.00              0.98
# 3            1.00   0.97                      1.00              0.98
# 4            1.00   0.97                      1.00              0.98
# 5            1.00   0.95                      1.00              0.97
# 6            1.00   0.92                      1.00              0.95
# 7            1.00   0.87                      1.00              0.93
# 8            0.84   0.75                      0.95              0.87
# 9            0.61   0.48                      0.86              0.77
# 10           0.18   0.25                      0.73              0.67
# 11           0.12   0.16                      0.63              0.58
# 12           0.06   0.12                      0.54              0.52
# 13           0.01   0.09                      0.48              0.46
# 14           0.01   0.07                      0.43              0.42
# 15           0.00   0.05                      0.38              0.38
#
#     capture_rate  cumulative_capture_rate    gain  cumulative_gain  \
# 0           0.03                     0.03  160.53           160.53
# 1           0.03                     0.05  160.53           160.53
# 2           0.03                     0.08  160.53           160.53
# 3           0.03                     0.11  160.53           160.53
# 4           0.03                     0.13  160.53           160.53
# 5           0.13                     0.26  160.53           160.53
# 6           0.13                     0.39  160.53           160.53
# 7           0.13                     0.52  160.53           160.53
# 8           0.22                     0.74  119.54           146.92
# 9           0.16                     0.90   58.07           124.77
# 10          0.05                     0.95  -53.16            89.26
# 11          0.03                     0.98  -67.80            63.13
# 12          0.01                     0.99  -85.36            41.95
# 13          0.00                     1.00  -97.11            24.43
# 14          0.00                     1.00  -97.04            11.10
# 15          0.00                     1.00 -100.00             0.00
#
#     kolmogorov_smirnov
# 0                 0.03
# 1                 0.05
# 2                 0.08
# 3                 0.11
# 4                 0.13
# 5                 0.26
# 6                 0.39
# 7                 0.52
# 8                 0.72
# 9                 0.81
# 10                0.73
# 11                0.62
# 12                0.48
# 13                0.32
# 14                0.16
# 15                0.00
# ModelMetricsBinomial: gbm
# ** Reported on cross-validation data. **
#
# MSE: 0.12242024427174984
# RMSE: 0.3498860446941973
# LogLoss: 0.40192205298777334
# Mean Per-Class Error: 0.17066915923689002
# AUC: 0.8767882060950798
# AUCPR: 0.8628759250766063
# Gini: 0.7535764121901596
#
# Confusion Matrix (Act/Pred) for max f1 @ threshold = 0.42156451330301314:
#               0      1   Error            Rate
# 0      0 482.00  67.00   0.122    (67.0/549.0)
# 1      1  75.00 267.00  0.2193    (75.0/342.0)
# 2  Total 557.00 334.00  0.1594   (142.0/891.0)
# Maximum Metrics: Maximum metrics at their respective thresholds
#                          metric  threshold  value    idx
# 0                        max f1       0.42   0.79 193.00
# 1                        max f2       0.23   0.81 259.00
# 2                  max f0point5       0.68   0.83 120.00
# 3                  max accuracy       0.51   0.85 165.00
# 4                 max precision       0.99   1.00   0.00
# 5                    max recall       0.02   1.00 397.00
# 6               max specificity       0.99   1.00   0.00
# 7              max absolute_mcc       0.50   0.67 168.00
# 8    max min_per_class_accuracy       0.33   0.81 220.00
# 9   max mean_per_class_accuracy       0.42   0.83 193.00
# 10                      max tns       0.99 549.00   0.00
# 11                      max fns       0.99 341.00   0.00
# 12                      max fps       0.01 549.00 399.00
# 13                      max tps       0.02 342.00 397.00
# 14                      max tnr       0.99   1.00   0.00
# 15                      max fnr       0.99   1.00   0.00
# 16                      max fpr       0.01   1.00 399.00
# 17                      max tpr       0.02   1.00 397.00
# Gains/Lift Table: Avg response rate: 38.38 %, avg score: 38.00 %
#     group  cumulative_data_fraction  lower_threshold  lift  cumulative_lift  \
# 0       1                      0.01             0.98  2.61             2.61
# 1       2                      0.02             0.97  2.61             2.61
# 2       3                      0.03             0.96  2.61             2.61
# 3       4                      0.04             0.95  2.61             2.61
# 4       5                      0.05             0.95  2.61             2.61
# 5       6                      0.10             0.91  2.61             2.61
# 6       7                      0.15             0.86  2.19             2.47
# 7       8                      0.20             0.79  2.32             2.43
# 8       9                      0.30             0.58  1.93             2.27
# 9      10                      0.40             0.37  1.17             1.99
# 10     11                      0.50             0.23  0.61             1.72
# 11     12                      0.60             0.15  0.26             1.48
# 12     13                      0.70             0.11  0.32             1.31
# 13     14                      0.80             0.09  0.26             1.18
# 14     15                      0.90             0.06  0.38             1.09
# 15     16                      1.00             0.01  0.18             1.00
#
#     response_rate  score  cumulative_response_rate  cumulative_score  \
# 0            1.00   0.98                      1.00              0.98
# 1            1.00   0.98                      1.00              0.98
# 2            1.00   0.97                      1.00              0.98
# 3            1.00   0.96                      1.00              0.97
# 4            1.00   0.95                      1.00              0.97
# 5            1.00   0.93                      1.00              0.95
# 6            0.84   0.89                      0.95              0.93
# 7            0.89   0.83                      0.93              0.91
# 8            0.74   0.70                      0.87              0.84
# 9            0.45   0.47                      0.76              0.75
# 10           0.24   0.29                      0.66              0.65
# 11           0.10   0.19                      0.57              0.58
# 12           0.12   0.13                      0.50              0.51
# 13           0.10   0.10                      0.45              0.46
# 14           0.15   0.07                      0.42              0.42
# 15           0.07   0.04                      0.38              0.38
#
#     capture_rate  cumulative_capture_rate   gain  cumulative_gain  \
# 0           0.03                     0.03 160.53           160.53
# 1           0.03                     0.05 160.53           160.53
# 2           0.03                     0.08 160.53           160.53
# 3           0.03                     0.11 160.53           160.53
# 4           0.03                     0.13 160.53           160.53
# 5           0.13                     0.26 160.53           160.53
# 6           0.11                     0.37 119.08           146.92
# 7           0.12                     0.49 131.58           143.06
# 8           0.19                     0.68  93.20           126.50
# 9           0.12                     0.80  17.09            99.23
# 10          0.06                     0.86 -38.53            71.74
# 11          0.03                     0.89 -73.65            47.55
# 12          0.03                     0.92 -67.80            31.10
# 13          0.03                     0.94 -73.65            18.02
# 14          0.04                     0.98 -61.95             9.15
# 15          0.02                     1.00 -82.44             0.00
#
#     kolmogorov_smirnov
# 0                 0.03
# 1                 0.05
# 2                 0.08
# 3                 0.11
# 4                 0.13
# 5                 0.26
# 6                 0.36
# 7                 0.47
# 8                 0.62
# 9                 0.65
# 10                0.58
# 11                0.46
# 12                0.35
# 13                0.23
# 14                0.13
# 15                0.00
# Cross-Validation Metrics Summary:
#                              mean   sd  cv_1_valid  cv_2_valid  cv_3_valid  \
# 0                  accuracy  0.85 0.05        0.87        0.86        0.77
# 1                       auc  0.87 0.03        0.89        0.88        0.82
# 2                       err  0.15 0.05        0.13        0.14        0.23
# 3                 err_count 26.60 8.62       23.00       25.00       41.00
# 4                  f0point5  0.81 0.07        0.84        0.82        0.69
# 5                        f1  0.81 0.05        0.83        0.83        0.72
# 6                        f2  0.81 0.03        0.82        0.84        0.75
# 7            lift_top_group  2.61 0.12        2.63        2.44        2.62
# 8                   logloss  0.41 0.06        0.38        0.38        0.50
# 9       max_per_class_error  0.19 0.03        0.19        0.15        0.24
# 10                      mcc  0.69 0.09        0.73        0.71        0.53
# 11  mean_per_class_accuracy  0.84 0.04        0.86        0.86        0.77
# 12     mean_per_class_error  0.16 0.04        0.14        0.14        0.23
# 13                      mse  0.12 0.02        0.11        0.11        0.16
# 14                   pr_auc  0.85 0.06        0.89        0.89        0.75
# 15                precision  0.81 0.08        0.85        0.82        0.67
# 16                       r2  0.48 0.10        0.53        0.54        0.32
# 17                   recall  0.81 0.03        0.81        0.85        0.78
# 18                     rmse  0.35 0.03        0.33        0.33        0.40
# 19              specificity  0.88 0.07        0.91        0.87        0.76
#
#     cv_4_valid  cv_5_valid
# 0         0.90        0.85
# 1         0.90        0.87
# 2         0.10        0.15
# 3        18.00       26.00
# 4         0.88        0.82
# 5         0.85        0.81
# 6         0.83        0.80
# 7         2.78        2.58
# 8         0.35        0.42
# 9         0.19        0.20
# 10        0.78        0.69
# 11        0.88        0.84
# 12        0.12        0.16
# 13        0.10        0.13
# 14        0.89        0.85
# 15        0.90        0.82
# 16        0.56        0.44
# 17        0.81        0.80
# 18        0.32        0.36
# 19        0.95        0.89
# Scoring History:
#                timestamp    duration  number_of_trees  training_rmse  \
# 0    2022-10-10 18:27:40   1.226 sec             0.00           0.49
# 1    2022-10-10 18:27:40   1.253 sec             5.00           0.40
# 2    2022-10-10 18:27:40   1.285 sec            10.00           0.35
# 3    2022-10-10 18:27:40   1.320 sec            15.00           0.33
# 4    2022-10-10 18:27:40   1.353 sec            20.00           0.31
# 5    2022-10-10 18:27:40   1.384 sec            25.00           0.30
# 6    2022-10-10 18:27:40   1.424 sec            30.00           0.28
# 7    2022-10-10 18:27:40   1.451 sec            35.00           0.28
# 8    2022-10-10 18:27:40   1.480 sec            40.00           0.27
#
#    training_logloss  training_auc  training_pr_auc  training_lift  \
# 0              0.67          0.50             0.38           1.00
# 1              0.51          0.92             0.91           2.61
# 2              0.42          0.94             0.92           2.61
# 3              0.37          0.94             0.93           2.61
# 4              0.33          0.95             0.94           2.61
# 5              0.31          0.96             0.94           2.61
# 6              0.29          0.96             0.95           2.61
# 7              0.27          0.96             0.95           2.61
# 8              0.26          0.96             0.95           2.61
#
#    training_classification_error
# 0                           0.62
# 1                           0.14
# 2                           0.12
# 3                           0.11
# 4                           0.10
# 5                           0.10
# 6                           0.10
# 7                           0.09
# 8                           0.09
# Variable Importances:
#    variable  relative_importance  scaled_importance  percentage
# 0       Sex               240.05               1.00        0.33
# 1       Age               175.09               0.73        0.24
# 2      Fare               130.63               0.54        0.18
# 3    Pclass               114.83               0.48        0.16
# 4     SibSp                30.20               0.13        0.04
# 5  Embarked                22.46               0.09        0.03
# 6     Parch                16.64               0.07        0.02

# %%
# Sort the evaluated models
automl.leaderboard
# Out:
# <table>
# <thead>
# <tr><th>model_id                                               </th><th style="text-align: right;">     auc</th><th style="text-align: right;">  logloss</th><th style="text-align: right;">   aucpr</th><th style="text-align: right;">  mean_per_class_error</th><th style="text-align: right;">    rmse</th><th style="text-align: right;">     mse</th></tr>
# </thead>
# <tbody>
# <tr><td>GBM_3_AutoML_1_20221010_182717                         </td><td style="text-align: right;">0.876788</td><td style="text-align: right;"> 0.401922</td><td style="text-align: right;">0.862876</td><td style="text-align: right;">              0.170669</td><td style="text-align: right;">0.349886</td><td style="text-align: right;">0.12242 </td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_1_AutoML_1_20221010_182717</td><td style="text-align: right;">0.874767</td><td style="text-align: right;"> 0.406227</td><td style="text-align: right;">0.858213</td><td style="text-align: right;">              0.17913 </td><td style="text-align: right;">0.352354</td><td style="text-align: right;">0.124153</td></tr>
# <tr><td>StackedEnsemble_AllModels_1_AutoML_1_20221010_182717   </td><td style="text-align: right;">0.872613</td><td style="text-align: right;"> 0.408971</td><td style="text-align: right;">0.858323</td><td style="text-align: right;">              0.176325</td><td style="text-align: right;">0.35257 </td><td style="text-align: right;">0.124305</td></tr>
# <tr><td>GBM_2_AutoML_1_20221010_182717                         </td><td style="text-align: right;">0.871582</td><td style="text-align: right;"> 0.409687</td><td style="text-align: right;">0.857846</td><td style="text-align: right;">              0.176277</td><td style="text-align: right;">0.354591</td><td style="text-align: right;">0.125735</td></tr>
# <tr><td>XGBoost_3_AutoML_1_20221010_182717                     </td><td style="text-align: right;">0.87131 </td><td style="text-align: right;"> 0.417834</td><td style="text-align: right;">0.847479</td><td style="text-align: right;">              0.180208</td><td style="text-align: right;">0.355459</td><td style="text-align: right;">0.126351</td></tr>
# <tr><td>GBM_4_AutoML_1_20221010_182717                         </td><td style="text-align: right;">0.870219</td><td style="text-align: right;"> 0.415496</td><td style="text-align: right;">0.852784</td><td style="text-align: right;">              0.176349</td><td style="text-align: right;">0.356529</td><td style="text-align: right;">0.127113</td></tr>
# <tr><td>XGBoost_2_AutoML_1_20221010_182717                     </td><td style="text-align: right;">0.868117</td><td style="text-align: right;"> 0.424171</td><td style="text-align: right;">0.841044</td><td style="text-align: right;">              0.191688</td><td style="text-align: right;">0.361474</td><td style="text-align: right;">0.130663</td></tr>
# <tr><td>DRF_1_AutoML_1_20221010_182717                         </td><td style="text-align: right;">0.861396</td><td style="text-align: right;"> 0.706447</td><td style="text-align: right;">0.831632</td><td style="text-align: right;">              0.193917</td><td style="text-align: right;">0.370478</td><td style="text-align: right;">0.137254</td></tr>
# <tr><td>XGBoost_1_AutoML_1_20221010_182717                     </td><td style="text-align: right;">0.860491</td><td style="text-align: right;"> 0.433248</td><td style="text-align: right;">0.834473</td><td style="text-align: right;">              0.202641</td><td style="text-align: right;">0.368405</td><td style="text-align: right;">0.135722</td></tr>
# <tr><td>XRT_1_AutoML_1_20221010_182717                         </td><td style="text-align: right;">0.858624</td><td style="text-align: right;"> 0.456702</td><td style="text-align: right;">0.813863</td><td style="text-align: right;">              0.192671</td><td style="text-align: right;">0.379698</td><td style="text-align: right;">0.144171</td></tr>
# </tbody>
# </table>

# %%
# Evaluation
y_pred = automl.predict(hf_train).as_data_frame()
y_pred = y_pred['predict'].tolist()
evaluate_model("h2o", y_train, y_pred)
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# Accuracy : 0.9068
# Precision: 0.8689
# Recall   : 0.8918
# F1-score : 0.8802

# %%
# Submission
def h2o_predict(hf_dataset):
    y_pred = automl.predict(hf_dataset).as_data_frame()
    y_pred = y_pred['predict'].tolist()
    return y_pred

create_submission(h2o_predict, hf_test, submission, "submission-h2o.csv")
# Out:
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%

# %%
# Results
pd.DataFrame(experiment).T.style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_a75f5_row0_col0, #T_a75f5_row0_col1, #T_a75f5_row0_col2, #T_a75f5_row0_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_a75f5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Acc</th>
#       <th class="col_heading level0 col1" >Pre</th>
#       <th class="col_heading level0 col2" >Rec</th>
#       <th class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a75f5_level0_row0" class="row_heading level0 row0" >lazypredict</th>
#       <td id="T_a75f5_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_a75f5_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_a75f5_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_a75f5_row0_col3" class="data row0 col3" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_a75f5_level0_row1" class="row_heading level0 row1" >tpot</th>
#       <td id="T_a75f5_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_a75f5_row1_col1" class="data row1 col1" >0.89</td>
#       <td id="T_a75f5_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_a75f5_row1_col3" class="data row1 col3" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_a75f5_level0_row2" class="row_heading level0 row2" >mljar</th>
#       <td id="T_a75f5_row2_col0" class="data row2 col0" >0.84</td>
#       <td id="T_a75f5_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_a75f5_row2_col2" class="data row2 col2" >0.71</td>
#       <td id="T_a75f5_row2_col3" class="data row2 col3" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_a75f5_level0_row3" class="row_heading level0 row3" >flaml</th>
#       <td id="T_a75f5_row3_col0" class="data row3 col0" >0.85</td>
#       <td id="T_a75f5_row3_col1" class="data row3 col1" >0.85</td>
#       <td id="T_a75f5_row3_col2" class="data row3 col2" >0.75</td>
#       <td id="T_a75f5_row3_col3" class="data row3 col3" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_a75f5_level0_row4" class="row_heading level0 row4" >auto-gluon</th>
#       <td id="T_a75f5_row4_col0" class="data row4 col0" >0.90</td>
#       <td id="T_a75f5_row4_col1" class="data row4 col1" >0.90</td>
#       <td id="T_a75f5_row4_col2" class="data row4 col2" >0.84</td>
#       <td id="T_a75f5_row4_col3" class="data row4 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_a75f5_level0_row5" class="row_heading level0 row5" >h2o</th>
#       <td id="T_a75f5_row5_col0" class="data row5 col0" >0.91</td>
#       <td id="T_a75f5_row5_col1" class="data row5 col1" >0.87</td>
#       <td id="T_a75f5_row5_col2" class="data row5 col2" >0.89</td>
#       <td id="T_a75f5_row5_col3" class="data row5 col3" >0.88</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Discussion
#
# Notes
# * **Bad** - It is not simple to install and use
# * **Bad** - It is not scikit-learn like
# * **Bad** - It does not use `pandas.DataFrame`, it uses `H2OFrame`
# * **Good** - It presents amazing results
#
# Features
# * **Good** - It includes preprocessing, model trainning and finetunning
#
# Public Score - 0.73444 (worse)

# %% [markdown]
# <a id="automl-autokeras"></a>
#
# ---
# # AutoKeras
#
# - [GitHub](https://github.com/keras-team/autokeras)
# - [Documentation](https://autokeras.com/)
#
# AutoKeras ia an AutoML system based on Keras, a Deep Learning library. AutoKeras can perform AutoML into different types of data, such as tabular, image or even text. Deep Learning models need tabular values as `int` or `float`, however can extract intrinsic features from the data - it tends to be good with real data.
#
# [> Back to Table of Contents](#ToC)

# %%
# %%capture
# Install AutoKeras
# !pip install autokeras==1.0.20

# %%
# %%time
import tensorflow as tf
import autokeras as ak

automl = ak.StructuredDataClassifier(overwrite=True, max_trials=10)
automl.fit(X_train, y_train,epochs=15)
# Out:
# Trial 10 Complete [00h 00m 08s]
# val_accuracy: 0.6387096643447876
#
# Best val_accuracy So Far: 0.8774193525314331
# Total elapsed time: 00h 01m 19s
# Epoch 1/15
# 28/28 [==============================] - 1s 3ms/step - loss: 0.6045 - accuracy: 0.7160
# Epoch 2/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.5051 - accuracy: 0.7811
# Epoch 3/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4653 - accuracy: 0.8058
# Epoch 4/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4460 - accuracy: 0.8114
# Epoch 5/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4345 - accuracy: 0.8137
# Epoch 6/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4264 - accuracy: 0.8182
# Epoch 7/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4201 - accuracy: 0.8182
# Epoch 8/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4151 - accuracy: 0.8227
# Epoch 9/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4112 - accuracy: 0.8215
# Epoch 10/15
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8215
# Epoch 11/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4051 - accuracy: 0.8238
# Epoch 12/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4027 - accuracy: 0.8283
# Epoch 13/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4006 - accuracy: 0.8294
# Epoch 14/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.3987 - accuracy: 0.8350
# Epoch 15/15
# 28/28 [==============================] - 0s 4ms/step - loss: 0.3969 - accuracy: 0.8339
# CPU times: user 1min 29s, sys: 4.06 s, total: 1min 33s
# Wall time: 1min 36s

# %%
# Evaluation
y_pred = automl.predict(X_train)
evaluate_model("auto-keras", y_train, y_pred)
# Out:
# 28/28 [==============================] - 0s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
# Accuracy : 0.8384
# Precision: 0.8750
# Recall   : 0.6754
# F1-score : 0.7624

# %%
# Submission
create_submission(automl.predict, X_test, submission, "submission-auto-keras.csv")
# Out:
# 14/14 [==============================] - 0s 3ms/step
# 14/14 [==============================] - 0s 4ms/step

# %%
# Results
pd.DataFrame(experiment).T.style.highlight_max(axis=0)
# Out:
# <style type="text/css">
# #T_11081_row0_col0, #T_11081_row0_col1, #T_11081_row0_col2, #T_11081_row0_col3 {
#   background-color: yellow;
# }
# </style>
# <table id="T_11081_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Acc</th>
#       <th class="col_heading level0 col1" >Pre</th>
#       <th class="col_heading level0 col2" >Rec</th>
#       <th class="col_heading level0 col3" >F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11081_level0_row0" class="row_heading level0 row0" >lazypredict</th>
#       <td id="T_11081_row0_col0" class="data row0 col0" >0.98</td>
#       <td id="T_11081_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_11081_row0_col2" class="data row0 col2" >0.96</td>
#       <td id="T_11081_row0_col3" class="data row0 col3" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_11081_level0_row1" class="row_heading level0 row1" >tpot</th>
#       <td id="T_11081_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_11081_row1_col1" class="data row1 col1" >0.89</td>
#       <td id="T_11081_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_11081_row1_col3" class="data row1 col3" >0.84</td>
#     </tr>
#     <tr>
#       <th id="T_11081_level0_row2" class="row_heading level0 row2" >mljar</th>
#       <td id="T_11081_row2_col0" class="data row2 col0" >0.84</td>
#       <td id="T_11081_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_11081_row2_col2" class="data row2 col2" >0.71</td>
#       <td id="T_11081_row2_col3" class="data row2 col3" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_11081_level0_row3" class="row_heading level0 row3" >flaml</th>
#       <td id="T_11081_row3_col0" class="data row3 col0" >0.85</td>
#       <td id="T_11081_row3_col1" class="data row3 col1" >0.85</td>
#       <td id="T_11081_row3_col2" class="data row3 col2" >0.75</td>
#       <td id="T_11081_row3_col3" class="data row3 col3" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_11081_level0_row4" class="row_heading level0 row4" >auto-gluon</th>
#       <td id="T_11081_row4_col0" class="data row4 col0" >0.90</td>
#       <td id="T_11081_row4_col1" class="data row4 col1" >0.90</td>
#       <td id="T_11081_row4_col2" class="data row4 col2" >0.84</td>
#       <td id="T_11081_row4_col3" class="data row4 col3" >0.87</td>
#     </tr>
#     <tr>
#       <th id="T_11081_level0_row5" class="row_heading level0 row5" >h2o</th>
#       <td id="T_11081_row5_col0" class="data row5 col0" >0.91</td>
#       <td id="T_11081_row5_col1" class="data row5 col1" >0.87</td>
#       <td id="T_11081_row5_col2" class="data row5 col2" >0.89</td>
#       <td id="T_11081_row5_col3" class="data row5 col3" >0.88</td>
#     </tr>
#     <tr>
#       <th id="T_11081_level0_row6" class="row_heading level0 row6" >auto-keras</th>
#       <td id="T_11081_row6_col0" class="data row6 col0" >0.84</td>
#       <td id="T_11081_row6_col1" class="data row6 col1" >0.88</td>
#       <td id="T_11081_row6_col2" class="data row6 col2" >0.68</td>
#       <td id="T_11081_row6_col3" class="data row6 col3" >0.76</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to install and use
# * **Good** - It presents good results
# * **Good** - It produces Deep Learning models
#
# Features
# * **Good** - It includes preprocessing and model trainning
# * **Good** - It can process tabular data, image and text
#
# Public Score - 0.77033 (good)

# %% [markdown]
# <a id="automl-mlbox"></a>
#
# ---
# # MLBox
#
# - [Example](https://www.kaggle.com/code/axelderomblay/running-mlbox-auto-ml-package-on-titanic/notebook)
# - [GitHub](https://github.com/AxeldeRomblay/MLBox)
# - [Documentation](https://mlbox.readthedocs.io/en/latest/)
#
# MLBox is a AutoML library that provides data preprocessing, feature selection, hyperparameter optimization and model evaluation. It contains several state-of-art competition models, such as Deep Learning, Stacking, LightGBM. Also, a few interpretation functions to analyze our results.
#
# [> Back to Table of Contents](#ToC)

# %% [markdown]
# _This code is written in markdown, because it uses incompatible packages for this Jupyter Notebook_
#
# **Installation**
#
# ```python
# %%capture
# # Downgrade main packages
# !pip install numpy==1.18.2 pandas==0.25.3
# !pip install scikit-learn==0.22.1 tensorflow==2.0.0
# # Install MLBox
# !pip install mlbox==0.8.5
# ```
#
# **Init**
#
# ```python
# # Init MLBox
# from mlbox.preprocessing import *
# from mlbox.optimisation import *
# from mlbox.prediction import *
# ```
#
# **Read data**
#
# ```python
# # Data infos
# target_name = "Survived"
# paths = ["../input/titanic/train.csv","../input/titanic/test.csv"]
#
# # Reading and Preprocessing Data
# rd = Reader(sep = ",")
# df = rd.train_test_split(paths, target_name)
# ```
#
# **Preprocessing**
#
# ```python
# # Auto removing unnecessary attributes
# dft = Drift_thresholder()
# df = dft.fit_transform(df)
# ```
#
# **AutoML**
#
# ```python
# space = {
#     'est__strategy':{"search":"choice", "space":["LightGBM"]},
#     'est__n_estimators':{"search":"choice", "space":[150]},
#     'est__colsample_bytree':{"search":"uniform", "space":[0.8,0.95]},
#     'est__subsample':{"search":"uniform", "space":[0.8,0.95]},
#     'est__max_depth':{"search":"choice", "space":[5,6,7,8,9]},
#     'est__learning_rate':{"search":"choice", "space":[0.07]}
# }
#
# # AutoML
# opt = Optimiser(scoring = "accuracy", n_folds = 5)
# params = opt.optimise(space, df, 15)
# ```
#
# **Submission**
#
# ```python
# # Making Predictions
# prd = Predictor()
# prd.fit_predict(params, df)
#
# # Reading the Results
# submit = pd.read_csv("../input/titanic/gender_submission.csv", sep=',')
# preds = pd.read_csv("save/"+target_name+"_predictions.csv")
#
# # Generating Submission
# submit[target_name] = preds[target_name+"_predicted"].values
# submit.to_csv("submission-mlbox.csv", index=False)
# ```

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to install
# * **Bad** - It is complex to use; far way from scikit-learn like
# * **Bad** - It did not work in Kaggle env (2022-08-25); but it worked in Google Colab
#
# Features
# * **Good** - It includes preprocessing and model trainning
#
# Public Score - 0.78708 (good)

# %% [markdown]
# <a id="automl-pycaret"></a>
#
# ---
# # PyCaret
#
# - [GitHub](https://github.com/pycaret/pycaret)
# - [Documentation](https://pycaret.org/)
#
# **PyCaret** is a low-code machine learning library that automates machine learning workflows. It is an end-to-end machine learning and model management tool that speeds up the experiment cycle exponentially and makes you more productive; AutoML is just one of the features of this package.
#
# [> Back to Table of Contents](#ToC)

# %% [markdown]
# _This code is written in markdown, because it uses incompatible packages for this Jupyter Notebook_
#
# **Installation**
#
# ```python
# %%capture
# # install pycaret
# !pip install llvmlite --ignore-installed
# !pip install pycaret==2.3.10
# !pip install numpy==1.20.3
# ```
#
# **Read data**
#
# ```python
# # Read data
# import numpy as np
# import pandas as pd
#
# train = pd.read_csv("/kaggle/input/titanic/train.csv")
# test  = pd.read_csv("/kaggle/input/titanic/test.csv")
# ```
#
# **AutoML**
#
# ```python
# %%time
# from pycaret import classification
#
# s = classification.setup(train, target = 'Survived')
# ```
#
# **Evaluation**
#
# ```python
# # Evaluation
# best = classification.compare_models()
# classification.plot_model(best)
# ```
#
# **Submission**
#
# ```python
# # Submission
# submission = classification.predict_model(best, data=test)
# submission = submission[['PassengerId', 'Label']].rename(columns={'Label': 'Survived'})
# submission.to_csv("submission-pycaret.csv", index=False)
# ```

# %% [markdown]
# ### Discussion
#
# Notes
# * **Good** - It is simple to install and use
# * **Good** - It is a complete tool, with different functionalities for ML-based production
# * **Bad** - It did not work in Kaggle env (2022-08-25); but it worked in Google Colab
#
# Features
# * **Good** - It includes preprocessing and model trainning; of complex models
# * **Good** - It includes clustering and anomaly detection also
#
# Public Score - 0.78229 (good)
